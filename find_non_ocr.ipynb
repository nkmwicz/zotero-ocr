# %% [markdown]
# # Find Non-OCR'd PDFs in Zotero Library
#
# This notebook identifies PDFs in your Zotero library that lack embedded text and need OCR preprocessing.
#
# **Strategy:**
# 1. Connect to Zotero library via pyzotero API
# 2. Download and analyze each PDF for text content
# 3. Identify PDFs that are image-only (need OCR)
# 4. Generate list for batch OCR preprocessing

# %%
# Install required packages if needed
# !pip install pyzotero langchain-community pymupdf

import os
import time
import json
from pathlib import Path
from typing import List, Dict, Tuple
import re

# PDF processing - Fast scan + PDFMiner verification
from langchain_community.document_loaders import PDFMinerLoader

try:
    import fitz  # PyMuPDF for fast scanning

    print("✅ PyMuPDF available for fast scanning")
except ImportError:
    print("⚠️  PyMuPDF not available - will use PDFMiner only (slower)")

# Zotero API
from pyzotero import zotero

print("📚 Zotero Non-OCR PDF Detection System")
print("⚡ Fast PyMuPDF scan + PDFMiner verification strategy")
print("🎯 Only verifies borderline cases for maximum speed")
print("=" * 50)
# Out:
# ✅ PyMuPDF available for fast scanning
# 📚 Zotero Non-OCR PDF Detection System
# ⚡ Fast PyMuPDF scan + PDFMiner verification strategy
# 🎯 Only verifies borderline cases for maximum speed
# ==================================================

# %% [markdown]
# ## Configuration
#
# Set up paths and detection parameters for your local Zotero storage scan.

# %%
# Configuration - SAFE COPY APPROACH
# Step 1: Copy your Zotero storage to a safe location first!
# cp -r ~/snap/zotero-snap/common/Zotero/storage ~/Desktop/zotero_storage_copy

# Option 1: Work on a SAFE COPY (RECOMMENDED!)
USE_SAFE_COPY = True
SAFE_COPY_PATH = Path("~/Desktop/zotero-storage-copy").expanduser()

# Option 2: Work on live storage (RISKY - not recommended)
# LIVE_STORAGE_PATH = Path("~/snap/zotero-snap/common/Zotero/storage/").expanduser()

# Choose which path to use
STORAGE_PATH = SAFE_COPY_PATH

# Optional: Zotero API for metadata lookup (read-only)
import os
import dotenv

dotenv.load_dotenv()

ZOTERO_USER_ID = os.getenv("ZOTERO_USER")  # Only needed for metadata lookup
ZOTERO_API_KEY = os.getenv("ZOTERO_API_KEY")  # Only needed for metadata lookup
ZOTERO_LIBRARY_TYPE = "user"  # "user" or "group"

# Detection Parameters
MIN_WORDS_PER_PAGE = 50  # Minimum words per page to consider "has text"
MAX_SAMPLE_PAGES = 10  # Number of pages to sample for detection

# Output Configuration
OUTPUT_DIR = Path("./ocr_analysis")
OUTPUT_DIR.mkdir(exist_ok=True)

print("🛡️  SAFE COPY MODE" if USE_SAFE_COPY else "⚠️  LIVE STORAGE MODE")
print(f"📁 Storage path: {STORAGE_PATH}")
print(f"📁 Output directory: {OUTPUT_DIR}")
print(f"⚙️  Detection threshold: {MIN_WORDS_PER_PAGE} words/page")

# Verify paths (FAST CHECK - don't enumerate all folders!)
if USE_SAFE_COPY:
    if not SAFE_COPY_PATH.exists():
        print(f"❌ Safe copy not found: {SAFE_COPY_PATH}")
        print("   Please run first:")
        print(f"   cp -r ~/snap/zotero-snap/common/Zotero/storage {SAFE_COPY_PATH}")
    else:
        # Fast check - just verify it's a directory, don't count folders
        print(f"✅ Safe copy found at: {SAFE_COPY_PATH}")
        print("✅ Safe to experiment without affecting live library!")
        print("📊 Folder counting will happen during scan (to avoid long startup)")
else:
    print("⚠️  WARNING: Working on live Zotero storage!")
    if STORAGE_PATH.exists():
        print(f"✅ Storage path found: {STORAGE_PATH}")
    else:
        print(f"❌ Storage path not found: {STORAGE_PATH}")

print("🚀 Configuration complete! Ready to scan.")
# Out:
# 🛡️  SAFE COPY MODE
# 📁 Storage path: /home/nkmwicz/Desktop/zotero-storage-copy
# 📁 Output directory: ocr_analysis
# ⚙️  Detection threshold: 50 words/page
# ✅ Safe copy found at: /home/nkmwicz/Desktop/zotero-storage-copy
# ✅ Safe to experiment without affecting live library!
# 📊 Folder counting will happen during scan (to avoid long startup)
# 🚀 Configuration complete! Ready to scan.

# %% [markdown]
# ## 🛡️ Super Safe Workflow
#
# **STEP 1: Create Safe Copy**
# ```bash
# # Copy Zotero storage to desktop (safe location)
# cp -r ~/snap/zotero-snap/common/Zotero/storage ~/Desktop/zotero_storage_copy
# ```
#
# **STEP 2: Run Analysis on Copy**
# - This notebook will analyze the **copy** (no risk to live library)
# - Generate list of PDFs needing OCR
# - Test OCR on sample files safely
#
# **STEP 3: Selective Integration**
# - OCR only the files you want to improve
# - Copy back only the successfully processed files
# - Your live library stays untouched until you explicitly choose to update it
#
# **Why This Is Perfect:**
# - ✅ Zero risk to synced library
# - ✅ Test OCR quality first
# - ✅ Selective updating
# - ✅ Perfect for large 23GB libraries

# %% [markdown]
# ## Text Detection Functions
#
# PDFMiner-only detection to match your actual processing pipeline exactly.

# %%
def analyze_pdf_text_content(pdf_path: str) -> Dict:
    """
    Fast PDF analysis with PDFMiner verification for accuracy.

    Strategy:
    1. Quick scan with PyMuPDF (100x faster)
    2. Only use PDFMiner for borderline cases
    3. Ensures compatibility with your clean_ocr_auto pipeline

    Returns:
        Dict with analysis results
    """
    from random import choice

    results = {
        "file_path": pdf_path,
        "file_size_mb": 0,
        "total_pages": 0,
        "has_extractable_text": False,
        "avg_words_per_page": 0,
        "total_characters": 0,
        "detection_method": "none",
        "sample_text": "",
        "error": None,
    }

    try:
        # Get file info
        file_stats = Path(pdf_path).stat()
        results["file_size_mb"] = file_stats.st_size / (1024 * 1024)

        # STEP 1: Fast scan with PyMuPDF
        try:
            import fitz

            doc = fitz.open(pdf_path)
            results["total_pages"] = len(doc)

            # Quick sample of first few pages
            sample_pages = min(5, len(doc))  # Just 5 pages for speed
            total_text = ""

            for _ in range(sample_pages):
                page_num = choice(range(len(doc)))
                page = doc[page_num]
                text = page.get_text()
                total_text += text

            doc.close()

            if total_text.strip():
                word_count = len(total_text.split())
                quick_words_per_page = word_count / sample_pages

                # CLEAR CASES - no need for PDFMiner verification
                if (
                    quick_words_per_page >= MIN_WORDS_PER_PAGE * 2
                ):  # Clearly has lots of text
                    results["avg_words_per_page"] = quick_words_per_page
                    results["total_characters"] = len(total_text)
                    results["sample_text"] = (
                        total_text[:200] + "..."
                        if len(total_text) > 200
                        else total_text
                    )
                    results["detection_method"] = "pymupdf_fast"
                    results["has_extractable_text"] = True
                    print(
                        f"   ⚡ FAST: Clearly has text ({quick_words_per_page:.1f} words/page)"
                    )
                    return results

                elif quick_words_per_page < 5:  # Clearly image-only
                    results["avg_words_per_page"] = quick_words_per_page
                    results["detection_method"] = "pymupdf_fast"
                    results["has_extractable_text"] = False
                    print(
                        f"   ⚡ FAST: Clearly image-only ({quick_words_per_page:.1f} words/page)"
                    )
                    return results

                else:
                    # BORDERLINE CASE - verify with PDFMiner
                    print(
                        f"   🔍 BORDERLINE: Verifying with PDFMiner ({quick_words_per_page:.1f} words/page)..."
                    )

            else:
                # No text found with PyMuPDF
                results["detection_method"] = "pymupdf_fast"
                results["has_extractable_text"] = False
                print(f"   ⚡ FAST: No text detected")
                return results

        except ImportError:
            print("   ⚠️  PyMuPDF not available, using PDFMiner only")
        except Exception as e:
            print(f"   ⚠️  PyMuPDF failed: {e}, trying PDFMiner")

        # STEP 2: PDFMiner verification (only for borderline cases or PyMuPDF failures)
        print(f"   🔍 PDFMiner verification...")
        loader = PDFMinerLoader(pdf_path)
        documents = loader.load()

        if documents and documents[0].page_content:
            total_text = documents[0].page_content.strip()

            if total_text:
                # Use actual page count from PyMuPDF if available
                estimated_pages = (
                    results["total_pages"]
                    if results["total_pages"] > 0
                    else max(1, len(total_text) // 3000)
                )
                results["total_pages"] = estimated_pages

                word_count = len(total_text.split())
                results["avg_words_per_page"] = word_count / estimated_pages
                results["total_characters"] = len(total_text)
                results["sample_text"] = (
                    total_text[:200] + "..." if len(total_text) > 200 else total_text
                )
                results["detection_method"] = "pdfminer_verified"

                if results["avg_words_per_page"] >= MIN_WORDS_PER_PAGE:
                    results["has_extractable_text"] = True
                    print(
                        f"      ✅ PDFMiner confirms: {word_count} words, {results['avg_words_per_page']:.1f} words/page"
                    )
                else:
                    print(
                        f"      ⚠️  PDFMiner: Minimal text ({results['avg_words_per_page']:.1f} words/page)"
                    )
            else:
                print(f"      ❌ PDFMiner: No extractable text")
        else:
            print(f"      ❌ PDFMiner: Could not load document")

    except Exception as e:
        results["error"] = str(e)
        print(f"      ❌ Analysis failed: {e}")

    return results


def classify_pdf_type(analysis: Dict) -> str:
    """
    Classify PDF based on analysis results.
    """
    if analysis["error"]:
        return "ERROR"
    elif analysis["has_extractable_text"]:
        return "HAS_TEXT"
    elif analysis["avg_words_per_page"] > 0:
        return "MINIMAL_TEXT"
    else:
        return "IMAGE_ONLY"


print("✅ Fast PDF detection with PDFMiner verification ready!")
print("⚡ Uses PyMuPDF for speed, PDFMiner for accuracy")
print("🎯 Only verifies borderline cases - much faster overall!")
# Out:
# ✅ Fast PDF detection with PDFMiner verification ready!
# ⚡ Uses PyMuPDF for speed, PDFMiner for accuracy
# 🎯 Only verifies borderline cases - much faster overall!

# %% [markdown]
# ## Local PDF Testing
#
# Test the detection system on your local PDFs first.

# %%
# Test on your local PDFs first
test_pdfs = [
    "./brantome.pdf",
    "./medici.pdf",
    "./brotton.pdf",
    "./vankley.pdf",
    "./henriiv.pdf",
    "./huguenots.pdf",
]

print("🧪 Testing detection system on local PDFs")
print("=" * 50)

test_results = []
for pdf_path in test_pdfs:
    if Path(pdf_path).exists():
        print(f"\n📄 Analyzing: {pdf_path}")
        analysis = analyze_pdf_text_content(pdf_path)
        classification = classify_pdf_type(analysis)

        print(f"   📊 Result: {classification}")
        print(f"   📏 Pages: {analysis['total_pages']}")
        print(f"   📝 Words/page: {analysis['avg_words_per_page']:.1f}")
        print(f"   🔧 Method: {analysis['detection_method']}")
        print(f"   💾 Size: {analysis['file_size_mb']:.1f} MB")

        if analysis["sample_text"]:
            print(f"   📖 Sample: {analysis['sample_text'][:100]}...")

        test_results.append({**analysis, "classification": classification})
    else:
        print(f"⚠️  File not found: {pdf_path}")

print(f"\n✅ Local testing complete! Analyzed {len(test_results)} PDFs")
# Out:
# 🧪 Testing detection system on local PDFs
# ==================================================
# ⚠️  File not found: ./brantome.pdf
# ⚠️  File not found: ./medici.pdf
# ⚠️  File not found: ./brotton.pdf
# ⚠️  File not found: ./vankley.pdf
# ⚠️  File not found: ./henriiv.pdf
# ⚠️  File not found: ./huguenots.pdf
#
# ✅ Local testing complete! Analyzed 0 PDFs

# %% [markdown]
# ## Local Storage Scanner
#
# Recursively scan your Zotero storage directory to find all PDFs and test their OCR status.

# %%
def scan_zotero_storage_directory():
    """
    Recursively scan Zotero storage directory for PDFs and analyze OCR status.

    Zotero storage structure:
    storage/
    ├── AB12CD34/  <- Zotero item key (8 characters)
    │   ├── document.pdf
    │   └── .zotero-ft-cache (full-text cache)
    ├── EF56GH78/
    │   └── another.pdf
    ...

    Returns:
        Dict with analysis results keyed by Zotero item key
    """
    print("🔍 Scanning Zotero storage directory...")
    print("=" * 50)

    if not STORAGE_PATH.exists():
        raise FileNotFoundError(f"Zotero storage not found: {STORAGE_PATH}")

    results = {
        "all_pdfs": {},
        "needs_ocr": [],
        "has_text": [],
        "errors": [],
        "no_pdfs": [],
        "total_folders": 0,
        "total_pdfs": 0,
    }

    # Get all storage folders (each is a Zotero item key)
    storage_folders = [f for f in STORAGE_PATH.iterdir() if f.is_dir()]
    results["total_folders"] = len(storage_folders)

    print(f"📁 Found {len(storage_folders)} storage folders to analyze")

    for i, folder in enumerate(storage_folders):
        folder_name = folder.name  # This is the Zotero item key

        if i % 100 == 0:  # Progress update every 100 folders
            print(f"   📊 Progress: {i}/{len(storage_folders)} folders...")

        # Find PDF files in this folder
        pdf_files = list(folder.glob("*.pdf"))

        if not pdf_files:
            results["no_pdfs"].append(folder_name)
            continue

        # Analyze the first PDF found (usually only one per folder)
        pdf_path = pdf_files[0]
        results["total_pdfs"] += 1

        try:
            analysis = analyze_pdf_text_content(str(pdf_path))
            analysis["zotero_key"] = folder_name
            analysis["folder_path"] = str(folder)
            analysis["pdf_filename"] = pdf_path.name

            classification = classify_pdf_type(analysis)
            analysis["classification"] = classification

            results["all_pdfs"][folder_name] = analysis

            # Categorize results
            if classification in ["IMAGE_ONLY", "MINIMAL_TEXT"]:
                results["needs_ocr"].append(folder_name)
            elif classification == "HAS_TEXT":
                results["has_text"].append(folder_name)
            else:
                results["errors"].append(folder_name)

        except Exception as e:
            print(f"   ❌ Error analyzing {folder_name}: {e}")
            error_analysis = {
                "zotero_key": folder_name,
                "folder_path": str(folder),
                "error": str(e),
                "classification": "ERROR",
            }
            results["all_pdfs"][folder_name] = error_analysis
            results["errors"].append(folder_name)

    # Summary
    print(f"\n📊 SCAN COMPLETE")
    print(f"   📁 Total folders: {results['total_folders']}")
    print(f"   📄 Total PDFs found: {results['total_pdfs']}")
    print(f"   ✅ PDFs with text: {len(results['has_text'])}")
    print(f"   🔍 PDFs needing OCR: {len(results['needs_ocr'])}")
    print(f"   ❌ Analysis errors: {len(results['errors'])}")
    print(f"   📂 Folders with no PDFs: {len(results['no_pdfs'])}")

    return results


def lookup_zotero_metadata(item_keys: List[str]) -> Dict:
    """
    Use Zotero API to get metadata for specific item keys.
    For PDF attachments, also fetches parent item metadata (books, articles, etc.)
    READ-ONLY operation - no writes to library.
    """
    if not ZOTERO_API_KEY or ZOTERO_API_KEY == "YOUR_API_KEY":
        print("⚠️  No Zotero API credentials - skipping metadata lookup")
        return {}

    print(f"🔍 Looking up metadata for {len(item_keys)} items...")

    try:
        zot = zotero.Zotero(ZOTERO_USER_ID, ZOTERO_LIBRARY_TYPE, ZOTERO_API_KEY)

        # Lookup items in batches (API limit is usually 50-100 items per request)
        batch_size = 50
        metadata = {}
        parent_keys_to_fetch = set()

        # STEP 1: Get attachment metadata and identify parent items
        for i in range(0, len(item_keys), batch_size):
            batch = item_keys[i : i + batch_size]
            print(
                f"   📥 Fetching batch {i//batch_size + 1}/{(len(item_keys)-1)//batch_size + 1} (attachments)"
            )

            try:
                # Get items by keys
                items = zot.items(itemKey=",".join(batch))

                for item in items:
                    key = item["key"]
                    data = item["data"]

                    # Store attachment metadata
                    attachment_metadata = {
                        "attachment_title": data.get("title", "Unknown Title"),
                        "attachment_type": data.get("itemType", "unknown"),
                        "parent_item_key": data.get("parentItem", ""),
                        "filename": data.get("filename", ""),
                        "content_type": data.get("contentType", ""),
                        "date_added": data.get("dateAdded", ""),
                        "date_modified": data.get("dateModified", ""),
                    }

                    metadata[key] = attachment_metadata

                    # If this is an attachment with a parent, we'll fetch parent metadata
                    if data.get("parentItem"):
                        parent_keys_to_fetch.add(data["parentItem"])

            except Exception as e:
                print(f"   ⚠️  Batch failed: {e}")
                continue

        # STEP 2: Get parent item metadata (the actual books/articles/etc.)
        if parent_keys_to_fetch:
            print(f"   📚 Fetching {len(parent_keys_to_fetch)} parent items...")
            parent_metadata = {}

            parent_keys_list = list(parent_keys_to_fetch)
            for i in range(0, len(parent_keys_list), batch_size):
                batch = parent_keys_list[i : i + batch_size]
                print(
                    f"   📥 Parent batch {i//batch_size + 1}/{(len(parent_keys_list)-1)//batch_size + 1}"
                )

                try:
                    parent_items = zot.items(itemKey=",".join(batch))

                    for item in parent_items:
                        parent_key = item["key"]
                        data = item["data"]

                        parent_metadata[parent_key] = {
                            "title": data.get("title", "Unknown Title"),
                            "item_type": data.get("itemType", "unknown"),
                            "language": data.get("language", "unknown"),
                            "authors": [
                                creator.get("firstName", "")
                                + " "
                                + creator.get("lastName", "")
                                for creator in data.get("creators", [])
                            ],
                            "publication_title": data.get("publicationTitle", ""),
                            "publisher": data.get("publisher", ""),
                            "date": data.get("date", ""),
                            "pages": data.get("pages", ""),
                            "volume": data.get("volume", ""),
                            "issue": data.get("issue", ""),
                            "url": data.get("url", ""),
                            "abstract": (
                                data.get("abstractNote", "")[:200] + "..."
                                if data.get("abstractNote", "")
                                else ""
                            ),
                        }

                except Exception as e:
                    print(f"   ⚠️  Parent batch failed: {e}")
                    continue

            # STEP 3: Merge parent metadata with attachment metadata
            for attachment_key, attachment_data in metadata.items():
                parent_key = attachment_data.get("parent_item_key")
                if parent_key and parent_key in parent_metadata:
                    # Add parent metadata to attachment record
                    attachment_data.update(parent_metadata[parent_key])

                    # Override title with parent title (more useful than attachment filename)
                    attachment_data["title"] = parent_metadata[parent_key]["title"]
                else:
                    # No parent found - use attachment data as fallback
                    attachment_data["title"] = attachment_data.get(
                        "attachment_title", "Unknown Title"
                    )
                    attachment_data["item_type"] = attachment_data.get(
                        "attachment_type", "attachment"
                    )
                    attachment_data["language"] = "unknown"
                    attachment_data["authors"] = []

        print(f"   ✅ Retrieved metadata for {len(metadata)} attachments")
        if parent_keys_to_fetch:
            print(
                f"   📚 Retrieved parent metadata for {len(parent_keys_to_fetch)} items"
            )
        return metadata

    except Exception as e:
        print(f"❌ Metadata lookup failed: {e}")
        return {}


print("✅ Storage scanner functions ready!")
# Out:
# ✅ Storage scanner functions ready!

# %% [markdown]
# ## Run Storage Analysis
#
# Scan your entire Zotero storage directory (this is much faster than API downloads!).

# %%
# Run the storage directory scan
print("🚀 Starting Zotero storage analysis...")
print("   This scans local files only - no downloads, no writes!")
print()

start_time = time.time()
storage_results = scan_zotero_storage_directory()
scan_time = time.time() - start_time

print(f"\n⏱️  Scan completed in {scan_time:.1f} seconds")
print(
    f"📊 Processing rate: {storage_results['total_pdfs']/scan_time:.1f} PDFs per second"
)

# Save raw results
raw_results_file = OUTPUT_DIR / "storage_scan_results.json"
with open(raw_results_file, "w") as f:
    json.dump(storage_results, f, indent=2, default=str)

print(f"💾 Raw results saved to: {raw_results_file}")
# Out:
# 🚀 Starting Zotero storage analysis...
#    This scans local files only - no downloads, no writes!
#
# 🔍 Scanning Zotero storage directory...
# ==================================================
# 📁 Found 3049 storage folders to analyze
#    📊 Progress: 0/3049 folders...
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (221.4 words/page)
#    ⚡ FAST: Clearly has text (599.4 words/page)
#    ⚡ FAST: Clearly has text (445.4 words/page)
#    ⚡ FAST: Clearly has text (511.8 words/page)
#    ⚡ FAST: Clearly has text (490.4 words/page)
#    ⚡ FAST: Clearly has text (326.4 words/page)
#    ⚡ FAST: Clearly has text (545.4 words/page)
#    ⚡ FAST: Clearly has text (465.6 words/page)
#    ⚡ FAST: Clearly has text (432.4 words/page)
#    ⚡ FAST: Clearly has text (347.0 words/page)
#    ⚡ FAST: Clearly has text (477.6 words/page)
#    ⚡ FAST: Clearly has text (375.8 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (447.0 words/page)
#    ⚡ FAST: Clearly has text (367.8 words/page)
#    ⚡ FAST: Clearly has text (746.5 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (485.2 words/page)
#    ⚡ FAST: Clearly has text (308.0 words/page)
#    ⚡ FAST: Clearly has text (490.8 words/page)
#    ⚡ FAST: Clearly has text (460.8 words/page)
#    ⚡ FAST: Clearly has text (465.4 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (287.0 words/page)
#    ⚡ FAST: Clearly has text (362.0 words/page)
#    ⚡ FAST: Clearly has text (233.6 words/page)
#    ⚡ FAST: Clearly has text (546.4 words/page)
#    ⚡ FAST: Clearly has text (604.6 words/page)
#    ⚡ FAST: Clearly has text (517.2 words/page)
#    ⚡ FAST: Clearly has text (587.4 words/page)
#    ⚡ FAST: Clearly has text (498.0 words/page)
#    ⚡ FAST: Clearly has text (598.6 words/page)
#    ⚡ FAST: Clearly has text (345.7 words/page)
#    ⚡ FAST: Clearly has text (357.0 words/page)
#    ⚡ FAST: Clearly has text (481.0 words/page)
#    ⚡ FAST: Clearly has text (558.2 words/page)
#    ⚡ FAST: Clearly has text (416.6 words/page)
#    ⚡ FAST: Clearly has text (598.6 words/page)
#    ⚡ FAST: Clearly has text (445.0 words/page)
#    ⚡ FAST: Clearly has text (437.4 words/page)
#    ⚡ FAST: Clearly has text (545.2 words/page)
#    ⚡ FAST: Clearly has text (532.8 words/page)
#    ⚡ FAST: Clearly has text (435.8 words/page)
#    ⚡ FAST: Clearly has text (501.2 words/page)
#    ⚡ FAST: Clearly has text (157.8 words/page)
#    ⚡ FAST: Clearly image-only (1.0 words/page)
#    ⚡ FAST: Clearly has text (343.4 words/page)
#    ⚡ FAST: Clearly has text (236.6 words/page)
#    ⚡ FAST: Clearly has text (398.0 words/page)
#    🔍 BORDERLINE: Verifying with PDFMiner (35.5 words/page)...
#    🔍 PDFMiner verification...
#       ⚠️  PDFMiner: Minimal text (35.0 words/page)
#    ⚡ FAST: Clearly has text (467.4 words/page)
#    ⚡ FAST: Clearly has text (464.0 words/page)
#    ⚡ FAST: Clearly has text (228.7 words/page)
#    ⚡ FAST: Clearly has text (270.2 words/page)
#    ⚡ FAST: Clearly has text (424.0 words/page)
#    ⚡ FAST: Clearly has text (529.6 words/page)
#    ⚡ FAST: Clearly has text (520.2 words/page)
#    ⚡ FAST: Clearly has text (505.6 words/page)
#    ⚡ FAST: Clearly has text (456.8 words/page)
#    ⚡ FAST: Clearly has text (333.6 words/page)
#    ⚡ FAST: Clearly has text (512.8 words/page)
#    ⚡ FAST: Clearly has text (726.4 words/page)
#    ⚡ FAST: Clearly has text (533.8 words/page)
#    ⚡ FAST: Clearly has text (504.6 words/page)
#    📊 Progress: 100/3049 folders...
#    ⚡ FAST: Clearly has text (526.4 words/page)
#    ⚡ FAST: Clearly has text (330.6 words/page)
#    ⚡ FAST: Clearly has text (765.0 words/page)
#    ⚡ FAST: Clearly has text (623.4 words/page)
#    ⚡ FAST: Clearly has text (427.4 words/page)
#    ⚡ FAST: Clearly has text (449.8 words/page)
#    ⚡ FAST: Clearly has text (465.0 words/page)
#    ⚡ FAST: Clearly has text (275.0 words/page)
#    ⚡ FAST: Clearly has text (389.2 words/page)
#    ⚡ FAST: Clearly has text (430.6 words/page)
#    ⚡ FAST: Clearly has text (260.0 words/page)
#    ⚡ FAST: Clearly has text (437.2 words/page)
#    ⚡ FAST: Clearly has text (412.0 words/page)
#    ⚡ FAST: Clearly has text (468.6 words/page)
#    ⚡ FAST: Clearly has text (441.4 words/page)
#    ⚡ FAST: Clearly has text (289.5 words/page)
#    ⚡ FAST: Clearly has text (332.4 words/page)
#    ⚡ FAST: Clearly has text (799.3 words/page)
#    🔍 BORDERLINE: Verifying with PDFMiner (54.0 words/page)...
#    🔍 PDFMiner verification...
#       ✅ PDFMiner confirms: 1035 words, 345.0 words/page
#    ⚡ FAST: Clearly has text (561.6 words/page)
#    ⚡ FAST: Clearly has text (471.5 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (514.4 words/page)
#    ⚡ FAST: Clearly has text (340.8 words/page)
#    ⚡ FAST: Clearly has text (569.4 words/page)
#    ⚡ FAST: Clearly has text (498.2 words/page)
#    ⚡ FAST: Clearly has text (276.4 words/page)
#    ⚡ FAST: Clearly has text (463.4 words/page)
#    ⚡ FAST: Clearly has text (463.6 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (353.8 words/page)
#    ⚡ FAST: Clearly has text (454.8 words/page)
#    ⚡ FAST: Clearly has text (511.6 words/page)
#    ⚡ FAST: Clearly has text (504.0 words/page)
#    ⚡ FAST: Clearly has text (352.2 words/page)
#    ⚡ FAST: Clearly has text (515.0 words/page)
#    ⚡ FAST: Clearly has text (404.8 words/page)
#    ⚡ FAST: Clearly has text (295.2 words/page)
#    ⚡ FAST: Clearly has text (539.0 words/page)
#    ⚡ FAST: Clearly has text (594.0 words/page)
#    ⚡ FAST: Clearly has text (408.2 words/page)
#    ⚡ FAST: Clearly has text (407.6 words/page)
#    ⚡ FAST: Clearly has text (478.2 words/page)
#    ⚡ FAST: Clearly has text (545.2 words/page)
#    ⚡ FAST: Clearly has text (449.4 words/page)
#    ⚡ FAST: Clearly has text (547.6 words/page)
#    ⚡ FAST: Clearly has text (456.2 words/page)
#    🔍 BORDERLINE: Verifying with PDFMiner (10.0 words/page)...
#    🔍 PDFMiner verification...
#       ⚠️  PDFMiner: Minimal text (10.6 words/page)
#    ⚡ FAST: Clearly has text (501.6 words/page)
#    ⚡ FAST: Clearly has text (529.6 words/page)
#    ⚡ FAST: Clearly has text (335.4 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (438.8 words/page)
#    ⚡ FAST: Clearly has text (424.0 words/page)
#    ⚡ FAST: Clearly has text (167.0 words/page)
#    ⚡ FAST: Clearly has text (149.4 words/page)
#    ⚡ FAST: Clearly has text (915.0 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (730.0 words/page)
#    ⚡ FAST: Clearly has text (407.0 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (533.2 words/page)
#    ⚡ FAST: Clearly has text (340.6 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (557.8 words/page)
#    ⚡ FAST: Clearly has text (365.6 words/page)
#    ⚡ FAST: Clearly has text (535.0 words/page)
#    ⚡ FAST: Clearly has text (592.2 words/page)
#    ⚡ FAST: Clearly has text (562.6 words/page)
#    ⚡ FAST: Clearly has text (516.6 words/page)
#    ⚡ FAST: Clearly has text (353.0 words/page)
#    ⚡ FAST: Clearly has text (423.6 words/page)
#    ⚡ FAST: Clearly has text (299.4 words/page)
#    ⚡ FAST: Clearly has text (454.2 words/page)
#    📊 Progress: 200/3049 folders...
#    ⚡ FAST: Clearly has text (530.4 words/page)
#    ⚡ FAST: Clearly has text (252.0 words/page)
#    ⚡ FAST: Clearly has text (375.6 words/page)
#    ⚡ FAST: Clearly has text (478.4 words/page)
#    ⚡ FAST: Clearly has text (373.6 words/page)
#    ⚡ FAST: Clearly has text (504.6 words/page)
#    ⚡ FAST: Clearly has text (318.2 words/page)
#    ⚡ FAST: Clearly has text (481.4 words/page)
#    ⚡ FAST: Clearly has text (515.0 words/page)
#    ⚡ FAST: Clearly has text (405.2 words/page)
#    ⚡ FAST: Clearly has text (107.2 words/page)
#    ⚡ FAST: Clearly has text (523.6 words/page)
#    ⚡ FAST: Clearly has text (438.6 words/page)
#    ⚡ FAST: Clearly has text (580.6 words/page)
#    ⚡ FAST: Clearly has text (497.8 words/page)
#    ⚡ FAST: Clearly has text (468.4 words/page)
#    ⚡ FAST: Clearly has text (292.8 words/page)
#    ⚡ FAST: Clearly has text (510.4 words/page)
#    ⚡ FAST: Clearly has text (593.6 words/page)
#    ⚡ FAST: Clearly has text (560.0 words/page)
#    ⚡ FAST: Clearly has text (656.0 words/page)
#    ⚡ FAST: Clearly has text (490.2 words/page)
#    ⚡ FAST: Clearly has text (513.8 words/page)
#    ⚡ FAST: Clearly has text (568.0 words/page)
#    ⚡ FAST: Clearly has text (377.6 words/page)
#    ⚡ FAST: Clearly has text (393.0 words/page)
#    ⚡ FAST: Clearly has text (412.2 words/page)
#    ⚡ FAST: Clearly has text (417.2 words/page)
#    ⚡ FAST: Clearly has text (671.8 words/page)
#    ⚡ FAST: Clearly has text (504.4 words/page)
#    ⚡ FAST: Clearly has text (505.0 words/page)
#    ⚡ FAST: Clearly has text (506.6 words/page)
#    🔍 BORDERLINE: Verifying with PDFMiner (53.8 words/page)...
#    🔍 PDFMiner verification...
#       ✅ PDFMiner confirms: 512 words, 85.3 words/page
#    ⚡ FAST: Clearly has text (440.8 words/page)
#    ⚡ FAST: Clearly has text (537.0 words/page)
#    ⚡ FAST: Clearly has text (522.4 words/page)
#    ⚡ FAST: Clearly has text (580.6 words/page)
#    ⚡ FAST: Clearly has text (575.2 words/page)
#    ⚡ FAST: Clearly has text (532.2 words/page)
#    ⚡ FAST: Clearly has text (343.8 words/page)
#    ⚡ FAST: Clearly has text (282.6 words/page)
#    ⚡ FAST: Clearly has text (383.0 words/page)
#    ⚡ FAST: Clearly has text (379.0 words/page)
#    🔍 BORDERLINE: Verifying with PDFMiner (25.2 words/page)...
#    🔍 PDFMiner verification...
#       ✅ PDFMiner confirms: 512 words, 85.3 words/page
#    ⚡ FAST: Clearly has text (464.8 words/page)
#    ⚡ FAST: Clearly has text (284.4 words/page)
#    ⚡ FAST: Clearly has text (577.0 words/page)
#    ⚡ FAST: Clearly has text (524.4 words/page)
#    ⚡ FAST: Clearly has text (391.0 words/page)
#    ⚡ FAST: Clearly has text (512.0 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (591.8 words/page)
#    ⚡ FAST: Clearly has text (811.0 words/page)
#    ⚡ FAST: Clearly has text (290.2 words/page)
#    ⚡ FAST: Clearly has text (459.2 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (502.2 words/page)
#    ⚡ FAST: Clearly has text (233.6 words/page)
#    ⚡ FAST: Clearly has text (446.8 words/page)
#    ⚡ FAST: Clearly has text (316.2 words/page)
#    ⚡ FAST: Clearly has text (590.6 words/page)
#    ⚡ FAST: Clearly has text (359.7 words/page)
#    ⚡ FAST: Clearly has text (413.8 words/page)
#    ⚡ FAST: Clearly has text (344.0 words/page)
#    ⚡ FAST: Clearly has text (567.4 words/page)
#    ⚡ FAST: Clearly has text (370.8 words/page)
#    ⚡ FAST: Clearly has text (500.0 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: No text detected
#    📊 Progress: 300/3049 folders...
#    ⚡ FAST: Clearly has text (259.0 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (495.2 words/page)
#    ⚡ FAST: Clearly has text (588.2 words/page)
#    ⚡ FAST: Clearly has text (377.6 words/page)
#    🔍 BORDERLINE: Verifying with PDFMiner (20.0 words/page)...
#    🔍 PDFMiner verification...
#       ⚠️  PDFMiner: Minimal text (25.4 words/page)
#    ⚡ FAST: Clearly has text (678.0 words/page)
#    ⚡ FAST: Clearly has text (542.4 words/page)
#    ⚡ FAST: Clearly has text (438.2 words/page)
#    ⚡ FAST: Clearly has text (349.0 words/page)
#    ⚡ FAST: Clearly has text (386.6 words/page)
#    ⚡ FAST: Clearly has text (471.4 words/page)
#    ⚡ FAST: Clearly has text (482.2 words/page)
#    ⚡ FAST: Clearly has text (618.4 words/page)
#    ⚡ FAST: Clearly has text (502.8 words/page)
#    ⚡ FAST: Clearly has text (451.6 words/page)
#    ⚡ FAST: Clearly has text (690.8 words/page)
#    ⚡ FAST: Clearly has text (487.8 words/page)
#    ⚡ FAST: Clearly has text (441.8 words/page)
#    ⚡ FAST: Clearly has text (858.2 words/page)
#    ⚡ FAST: Clearly has text (525.4 words/page)
#    ⚡ FAST: Clearly has text (452.8 words/page)
#    ⚡ FAST: Clearly has text (515.2 words/page)
#    ⚡ FAST: Clearly has text (571.6 words/page)
#    ⚡ FAST: Clearly has text (365.0 words/page)
#    ⚡ FAST: Clearly has text (433.0 words/page)
#    ⚡ FAST: Clearly has text (459.8 words/page)
#    🔍 BORDERLINE: Verifying with PDFMiner (58.0 words/page)...
#    🔍 PDFMiner verification...
#       ✅ PDFMiner confirms: 843 words, 140.5 words/page
#    ⚡ FAST: Clearly has text (389.6 words/page)
#    ⚡ FAST: Clearly has text (521.6 words/page)
#    ⚡ FAST: Clearly has text (573.0 words/page)
#    ⚡ FAST: Clearly has text (438.2 words/page)
#    ⚡ FAST: Clearly has text (512.6 words/page)
#    ⚡ FAST: Clearly has text (192.3 words/page)
#    ⚡ FAST: Clearly has text (992.8 words/page)
#    ⚡ FAST: Clearly has text (278.6 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (485.2 words/page)
#    ⚡ FAST: Clearly has text (483.0 words/page)
#    ⚡ FAST: Clearly has text (504.8 words/page)
#    ⚡ FAST: Clearly has text (577.0 words/page)
#    ⚡ FAST: Clearly has text (391.0 words/page)
#    ⚡ FAST: Clearly has text (553.2 words/page)
#    ⚡ FAST: Clearly has text (610.8 words/page)
#    ⚡ FAST: Clearly has text (490.8 words/page)
#    ⚡ FAST: Clearly has text (473.6 words/page)
#    ⚡ FAST: Clearly has text (438.4 words/page)
#    ⚡ FAST: Clearly has text (433.8 words/page)
#    ⚡ FAST: Clearly has text (798.4 words/page)
#    ⚡ FAST: Clearly has text (509.6 words/page)
#    ⚡ FAST: Clearly has text (441.8 words/page)
#    ⚡ FAST: Clearly has text (286.4 words/page)
#    ⚡ FAST: Clearly has text (206.7 words/page)
#    ⚡ FAST: Clearly has text (309.2 words/page)
#    ⚡ FAST: Clearly has text (420.0 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (509.4 words/page)
#    ⚡ FAST: Clearly has text (592.6 words/page)
#    ⚡ FAST: Clearly has text (339.2 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (445.4 words/page)
#    ⚡ FAST: Clearly has text (309.0 words/page)
#    ⚡ FAST: Clearly has text (606.0 words/page)
#    ⚡ FAST: Clearly has text (251.8 words/page)
#    ⚡ FAST: Clearly has text (709.8 words/page)
#    ⚡ FAST: Clearly has text (218.0 words/page)
#    ⚡ FAST: Clearly has text (423.0 words/page)
#    ⚡ FAST: Clearly has text (526.8 words/page)
#    ⚡ FAST: Clearly has text (345.3 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (562.8 words/page)
#    ⚡ FAST: Clearly has text (421.6 words/page)
#    🔍 BORDERLINE: Verifying with PDFMiner (29.8 words/page)...
#    🔍 PDFMiner verification...
#       ⚠️  PDFMiner: Minimal text (25.2 words/page)
#    ⚡ FAST: Clearly has text (401.4 words/page)
#    🔍 BORDERLINE: Verifying with PDFMiner (94.8 words/page)...
#    🔍 PDFMiner verification...
#       ✅ PDFMiner confirms: 843 words, 140.5 words/page
#    📊 Progress: 400/3049 folders...
#    🔍 BORDERLINE: Verifying with PDFMiner (12.0 words/page)...
#    🔍 PDFMiner verification...
#       ⚠️  PDFMiner: Minimal text (22.0 words/page)
#    ⚡ FAST: Clearly has text (744.4 words/page)
#    ⚡ FAST: Clearly has text (376.2 words/page)
#    ⚡ FAST: Clearly has text (231.6 words/page)
#    ⚡ FAST: Clearly has text (561.0 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (527.2 words/page)
#    ⚡ FAST: Clearly has text (390.0 words/page)
#    ⚡ FAST: Clearly has text (513.0 words/page)
#    ⚡ FAST: Clearly has text (288.2 words/page)
#    ⚡ FAST: Clearly has text (393.2 words/page)
#    ⚡ FAST: Clearly has text (435.8 words/page)
#    ⚡ FAST: Clearly has text (437.0 words/page)
#    ⚡ FAST: Clearly has text (171.2 words/page)
#    ⚡ FAST: Clearly has text (419.4 words/page)
#    ⚡ FAST: Clearly has text (327.2 words/page)
#    ⚡ FAST: Clearly has text (491.0 words/page)
#    ⚡ FAST: Clearly has text (419.6 words/page)
#    ⚡ FAST: Clearly has text (557.4 words/page)
#    ⚡ FAST: Clearly has text (403.6 words/page)
#    ⚡ FAST: Clearly has text (437.0 words/page)
#    ⚡ FAST: Clearly has text (383.2 words/page)
#    ⚡ FAST: Clearly has text (558.0 words/page)
#    ⚡ FAST: Clearly has text (468.0 words/page)
#    ⚡ FAST: Clearly has text (375.6 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (374.4 words/page)
#    ⚡ FAST: Clearly has text (503.2 words/page)
#    ⚡ FAST: Clearly has text (520.0 words/page)
#    ⚡ FAST: Clearly has text (680.4 words/page)
#    ⚡ FAST: Clearly has text (385.0 words/page)
#    ⚡ FAST: Clearly has text (377.2 words/page)
#    ⚡ FAST: Clearly has text (403.0 words/page)
#    ⚡ FAST: Clearly has text (467.8 words/page)
#    ⚡ FAST: Clearly has text (400.0 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (417.0 words/page)
#    ⚡ FAST: Clearly has text (884.8 words/page)
#    ⚡ FAST: Clearly has text (235.6 words/page)
#    ⚡ FAST: Clearly has text (550.5 words/page)
#    ⚡ FAST: Clearly has text (590.8 words/page)
#    ⚡ FAST: Clearly has text (778.2 words/page)
#    ⚡ FAST: Clearly has text (297.5 words/page)
#    ⚡ FAST: Clearly has text (335.2 words/page)
#    ⚡ FAST: Clearly has text (630.6 words/page)
#    ⚡ FAST: Clearly has text (436.6 words/page)
#    ⚡ FAST: Clearly has text (206.6 words/page)
#    ⚡ FAST: Clearly has text (421.6 words/page)
#    ⚡ FAST: Clearly has text (213.5 words/page)
#    ⚡ FAST: Clearly has text (577.4 words/page)
#    🔍 BORDERLINE: Verifying with PDFMiner (66.2 words/page)...
#    🔍 PDFMiner verification...
#       ✅ PDFMiner confirms: 843 words, 140.5 words/page
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (1137.0 words/page)
#    ⚡ FAST: Clearly has text (432.6 words/page)
#    ⚡ FAST: Clearly has text (325.2 words/page)
#    ⚡ FAST: Clearly has text (382.6 words/page)
#    ⚡ FAST: Clearly has text (207.0 words/page)
#    ⚡ FAST: Clearly has text (538.2 words/page)
#    ⚡ FAST: Clearly has text (525.4 words/page)
#    ⚡ FAST: Clearly has text (294.2 words/page)
#    ⚡ FAST: Clearly has text (659.6 words/page)
#    ⚡ FAST: Clearly has text (394.4 words/page)
#    ⚡ FAST: Clearly has text (405.8 words/page)
#    ⚡ FAST: Clearly has text (111.6 words/page)
#    ⚡ FAST: Clearly has text (449.4 words/page)
#    ⚡ FAST: Clearly has text (445.0 words/page)
#    ⚡ FAST: Clearly has text (442.0 words/page)
#    ⚡ FAST: Clearly has text (445.6 words/page)
#    ⚡ FAST: Clearly has text (478.6 words/page)
#    ⚡ FAST: Clearly has text (345.8 words/page)
#    📊 Progress: 500/3049 folders...
#    ⚡ FAST: Clearly has text (954.8 words/page)
#    ⚡ FAST: Clearly has text (332.8 words/page)
#    ⚡ FAST: Clearly has text (409.2 words/page)
#    ⚡ FAST: Clearly has text (540.4 words/page)
#    ⚡ FAST: Clearly has text (426.8 words/page)
#    ⚡ FAST: Clearly has text (452.4 words/page)
#    ⚡ FAST: Clearly has text (418.2 words/page)
#    ⚡ FAST: Clearly has text (275.2 words/page)
#    ⚡ FAST: Clearly has text (614.8 words/page)
#    ⚡ FAST: Clearly has text (656.4 words/page)
#    ⚡ FAST: Clearly has text (567.2 words/page)
#    🔍 BORDERLINE: Verifying with PDFMiner (95.8 words/page)...
#    🔍 PDFMiner verification...
#       ✅ PDFMiner confirms: 843 words, 140.5 words/page
#    ⚡ FAST: Clearly has text (391.4 words/page)
#    ⚡ FAST: Clearly has text (506.2 words/page)
#    ⚡ FAST: Clearly has text (506.0 words/page)
#    ⚡ FAST: Clearly has text (836.2 words/page)
#    ⚡ FAST: Clearly has text (505.0 words/page)
#    ⚡ FAST: Clearly has text (422.0 words/page)
#    ⚡ FAST: Clearly has text (556.4 words/page)
#    ⚡ FAST: Clearly has text (398.0 words/page)
#    ⚡ FAST: Clearly has text (252.6 words/page)
#    ⚡ FAST: Clearly has text (376.6 words/page)
#    ⚡ FAST: Clearly has text (287.0 words/page)
#    ⚡ FAST: Clearly has text (455.4 words/page)
#    ⚡ FAST: Clearly has text (422.6 words/page)
#    ⚡ FAST: Clearly has text (415.0 words/page)
#    ⚡ FAST: Clearly has text (559.6 words/page)
#    ⚡ FAST: Clearly has text (427.0 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (737.6 words/page)
#    ⚡ FAST: Clearly has text (966.7 words/page)
#    ⚡ FAST: Clearly has text (496.6 words/page)
#    ⚡ FAST: Clearly has text (323.0 words/page)
#    ⚡ FAST: Clearly has text (326.8 words/page)
#    ⚡ FAST: Clearly has text (439.4 words/page)
#    ⚡ FAST: Clearly has text (529.2 words/page)
#    ⚡ FAST: Clearly has text (598.0 words/page)
#    ⚡ FAST: Clearly has text (182.6 words/page)
#    ⚡ FAST: Clearly has text (501.6 words/page)
#    ⚡ FAST: Clearly has text (411.6 words/page)
#    ⚡ FAST: Clearly has text (450.0 words/page)
#    ⚡ FAST: Clearly has text (849.0 words/page)
#    ⚡ FAST: Clearly has text (450.6 words/page)
#    ⚡ FAST: Clearly has text (391.0 words/page)
#    ⚡ FAST: Clearly has text (824.8 words/page)
#    ⚡ FAST: Clearly has text (448.8 words/page)
#    ⚡ FAST: Clearly has text (337.0 words/page)
#    ⚡ FAST: Clearly has text (340.0 words/page)
#    ⚡ FAST: Clearly has text (288.2 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (421.6 words/page)
#    ⚡ FAST: Clearly has text (510.8 words/page)
#    ⚡ FAST: No text detected
#    🔍 BORDERLINE: Verifying with PDFMiner (95.8 words/page)...
#    🔍 PDFMiner verification...
#       ✅ PDFMiner confirms: 843 words, 140.5 words/page
#    ⚡ FAST: Clearly has text (516.4 words/page)
#    ⚡ FAST: Clearly has text (378.2 words/page)
#    ⚡ FAST: Clearly has text (197.8 words/page)
#    ⚡ FAST: Clearly has text (524.4 words/page)
#    ⚡ FAST: Clearly has text (371.4 words/page)
#    📊 Progress: 600/3049 folders...
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (511.0 words/page)
#    ⚡ FAST: Clearly has text (448.2 words/page)
#    ⚡ FAST: Clearly has text (434.0 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (415.8 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (459.4 words/page)
#    ⚡ FAST: Clearly has text (475.8 words/page)
#    ⚡ FAST: Clearly has text (491.2 words/page)
#    ⚡ FAST: Clearly has text (361.4 words/page)
#    ⚡ FAST: Clearly has text (508.2 words/page)
#    ⚡ FAST: Clearly has text (339.8 words/page)
#    ⚡ FAST: Clearly has text (483.2 words/page)
#    ⚡ FAST: Clearly has text (581.0 words/page)
#    ⚡ FAST: Clearly has text (603.8 words/page)
#    ⚡ FAST: Clearly has text (377.2 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (344.4 words/page)
#    ⚡ FAST: Clearly has text (586.8 words/page)
#    ⚡ FAST: Clearly has text (439.8 words/page)
#    ⚡ FAST: Clearly has text (386.0 words/page)
#    ⚡ FAST: Clearly has text (488.4 words/page)
#    🔍 BORDERLINE: Verifying with PDFMiner (63.2 words/page)...
#    🔍 PDFMiner verification...
#       ✅ PDFMiner confirms: 843 words, 140.5 words/page
#    ⚡ FAST: Clearly has text (543.8 words/page)
#    ⚡ FAST: Clearly has text (591.0 words/page)
#    ⚡ FAST: Clearly has text (294.6 words/page)
#    ⚡ FAST: Clearly has text (348.0 words/page)
#    ⚡ FAST: Clearly has text (388.2 words/page)
#    ⚡ FAST: Clearly has text (472.6 words/page)
#    ⚡ FAST: Clearly has text (406.8 words/page)
#    ⚡ FAST: Clearly has text (367.0 words/page)
#    ⚡ FAST: Clearly has text (439.0 words/page)
#    ⚡ FAST: Clearly has text (580.8 words/page)
#    ⚡ FAST: Clearly has text (437.2 words/page)
#    ⚡ FAST: Clearly has text (513.8 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (411.6 words/page)
#    ⚡ FAST: Clearly has text (323.4 words/page)
#    ⚡ FAST: Clearly has text (553.8 words/page)
#    ⚡ FAST: Clearly has text (616.4 words/page)
#    ⚡ FAST: Clearly has text (564.8 words/page)
#    ⚡ FAST: Clearly has text (389.0 words/page)
#    ⚡ FAST: Clearly has text (538.2 words/page)
#    ⚡ FAST: Clearly has text (649.8 words/page)
#    ⚡ FAST: Clearly has text (411.0 words/page)
#    ⚡ FAST: Clearly has text (499.6 words/page)
#    ⚡ FAST: Clearly has text (595.4 words/page)
#    ⚡ FAST: Clearly has text (444.8 words/page)
#    ⚡ FAST: Clearly has text (496.2 words/page)
#    ⚡ FAST: Clearly has text (523.6 words/page)
#    ⚡ FAST: Clearly has text (464.6 words/page)
#    ⚡ FAST: Clearly has text (495.6 words/page)
#    ⚡ FAST: Clearly has text (174.2 words/page)
#    ⚡ FAST: Clearly has text (538.6 words/page)
#    ⚡ FAST: Clearly has text (524.8 words/page)
#    ⚡ FAST: Clearly has text (596.6 words/page)
#    ⚡ FAST: Clearly has text (439.6 words/page)
#    ⚡ FAST: Clearly has text (452.0 words/page)
#    ⚡ FAST: Clearly has text (339.4 words/page)
#    ⚡ FAST: Clearly has text (476.4 words/page)
#    ⚡ FAST: Clearly has text (474.6 words/page)
#    ⚡ FAST: Clearly has text (514.0 words/page)
#    ⚡ FAST: Clearly has text (548.8 words/page)
#    ⚡ FAST: Clearly has text (544.8 words/page)
#    ⚡ FAST: Clearly has text (226.3 words/page)
#    📊 Progress: 700/3049 folders...
#    ⚡ FAST: Clearly has text (467.4 words/page)
#    ⚡ FAST: Clearly has text (574.0 words/page)
#    ⚡ FAST: Clearly has text (687.8 words/page)
#    ⚡ FAST: Clearly has text (536.0 words/page)
#    ⚡ FAST: Clearly has text (400.2 words/page)
#    ⚡ FAST: Clearly has text (484.8 words/page)
#    ⚡ FAST: Clearly has text (392.4 words/page)
#    ⚡ FAST: Clearly has text (159.2 words/page)
#    ⚡ FAST: Clearly has text (264.8 words/page)
#    ⚡ FAST: Clearly has text (469.4 words/page)
#    ⚡ FAST: Clearly has text (384.2 words/page)
#    ⚡ FAST: Clearly has text (483.0 words/page)
#    ⚡ FAST: Clearly has text (397.2 words/page)
#    ⚡ FAST: Clearly has text (165.0 words/page)
#    ⚡ FAST: Clearly has text (325.6 words/page)
#    ⚡ FAST: Clearly has text (423.5 words/page)
#    ⚡ FAST: Clearly has text (350.4 words/page)
#    ⚡ FAST: Clearly has text (437.6 words/page)
#    ⚡ FAST: Clearly has text (563.4 words/page)
#    ⚡ FAST: Clearly has text (467.6 words/page)
#    ⚡ FAST: Clearly has text (436.4 words/page)
#    ⚡ FAST: Clearly has text (478.2 words/page)
#    ⚡ FAST: Clearly has text (455.6 words/page)
#    ⚡ FAST: Clearly has text (503.8 words/page)
#    ⚡ FAST: Clearly has text (348.0 words/page)
#    ⚡ FAST: Clearly has text (603.4 words/page)
#    ⚡ FAST: Clearly has text (607.4 words/page)
#    ⚡ FAST: Clearly has text (529.3 words/page)
#    ⚡ FAST: Clearly has text (490.8 words/page)
#    ⚡ FAST: Clearly has text (514.2 words/page)
#    ⚡ FAST: Clearly has text (466.6 words/page)
#    ⚡ FAST: Clearly has text (407.6 words/page)
#    ⚡ FAST: Clearly has text (494.2 words/page)
#    ⚡ FAST: Clearly has text (374.8 words/page)
#    ⚡ FAST: Clearly has text (329.2 words/page)
#    🔍 BORDERLINE: Verifying with PDFMiner (12.0 words/page)...
#    🔍 PDFMiner verification...
#       ⚠️  PDFMiner: Minimal text (13.5 words/page)
#    ⚡ FAST: Clearly has text (499.6 words/page)
#    ⚡ FAST: Clearly has text (495.0 words/page)
#    ⚡ FAST: Clearly has text (499.2 words/page)
#    🔍 BORDERLINE: Verifying with PDFMiner (30.0 words/page)...
#    🔍 PDFMiner verification...
#       ⚠️  PDFMiner: Minimal text (42.9 words/page)
#    ⚡ FAST: Clearly has text (445.8 words/page)
#    ⚡ FAST: Clearly has text (592.6 words/page)
#    ⚡ FAST: Clearly has text (411.2 words/page)
#    ⚡ FAST: Clearly has text (718.4 words/page)
#    ⚡ FAST: Clearly has text (320.2 words/page)
#    🔍 BORDERLINE: Verifying with PDFMiner (74.6 words/page)...
#    🔍 PDFMiner verification...
#       ✅ PDFMiner confirms: 843 words, 140.5 words/page
#    ⚡ FAST: Clearly has text (465.2 words/page)
#    ⚡ FAST: Clearly has text (677.4 words/page)
#    ⚡ FAST: Clearly has text (361.2 words/page)
#    ⚡ FAST: Clearly has text (475.0 words/page)
#    ⚡ FAST: Clearly has text (429.6 words/page)
#    ⚡ FAST: Clearly has text (408.0 words/page)
#    ⚡ FAST: Clearly has text (554.8 words/page)
#    ⚡ FAST: Clearly has text (503.0 words/page)
#    ⚡ FAST: Clearly has text (349.6 words/page)
#    ⚡ FAST: Clearly has text (557.8 words/page)
#    🔍 BORDERLINE: Verifying with PDFMiner (87.6 words/page)...
#    🔍 PDFMiner verification...
#       ✅ PDFMiner confirms: 512 words, 85.3 words/page
#    ⚡ FAST: Clearly has text (503.6 words/page)
#    ⚡ FAST: Clearly has text (457.4 words/page)
#    ⚡ FAST: Clearly has text (294.2 words/page)
#    ⚡ FAST: Clearly has text (356.7 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (511.6 words/page)
#    🔍 BORDERLINE: Verifying with PDFMiner (27.8 words/page)...
#    🔍 PDFMiner verification...
#       ✅ PDFMiner confirms: 843 words, 140.5 words/page
#    ⚡ FAST: Clearly has text (409.6 words/page)
#    ⚡ FAST: Clearly has text (486.4 words/page)
#    ⚡ FAST: Clearly has text (456.2 words/page)
#    ⚡ FAST: Clearly has text (609.3 words/page)
#    ⚡ FAST: Clearly has text (471.2 words/page)
#    📊 Progress: 800/3049 folders...
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (570.4 words/page)
#    ⚡ FAST: Clearly has text (654.6 words/page)
#    ⚡ FAST: Clearly has text (443.6 words/page)
#    ⚡ FAST: Clearly has text (334.0 words/page)
#    ⚡ FAST: Clearly has text (495.2 words/page)
#    ⚡ FAST: Clearly has text (569.6 words/page)
#    ⚡ FAST: Clearly has text (215.6 words/page)
#    ⚡ FAST: Clearly has text (454.8 words/page)
#    ⚡ FAST: Clearly has text (421.2 words/page)
#    ⚡ FAST: Clearly has text (255.0 words/page)
#    ⚡ FAST: Clearly has text (475.2 words/page)
#    ⚡ FAST: Clearly has text (471.0 words/page)
#    ⚡ FAST: Clearly has text (965.0 words/page)
#    ⚡ FAST: Clearly has text (968.8 words/page)
#    ⚡ FAST: Clearly has text (612.8 words/page)
#    🔍 BORDERLINE: Verifying with PDFMiner (33.4 words/page)...
#    🔍 PDFMiner verification...
#       ✅ PDFMiner confirms: 843 words, 140.5 words/page
#    ⚡ FAST: Clearly has text (513.2 words/page)
#    ⚡ FAST: Clearly has text (413.6 words/page)
#    ⚡ FAST: No text detected
#    🔍 BORDERLINE: Verifying with PDFMiner (69.6 words/page)...
#    🔍 PDFMiner verification...
#       ✅ PDFMiner confirms: 512 words, 85.3 words/page
#    ⚡ FAST: Clearly has text (539.8 words/page)
#    ⚡ FAST: Clearly has text (406.2 words/page)
#    ⚡ FAST: Clearly has text (578.4 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (511.2 words/page)
#    ⚡ FAST: Clearly has text (511.6 words/page)
#    ⚡ FAST: Clearly has text (391.8 words/page)
#    ⚡ FAST: Clearly has text (545.8 words/page)
#    ⚡ FAST: Clearly has text (350.0 words/page)
#    ⚡ FAST: Clearly has text (492.0 words/page)
#    ⚡ FAST: Clearly has text (561.0 words/page)
#    ⚡ FAST: Clearly has text (398.8 words/page)
#    ⚡ FAST: Clearly has text (575.2 words/page)
#    ⚡ FAST: Clearly has text (436.0 words/page)
#    ⚡ FAST: Clearly has text (584.2 words/page)
#    ⚡ FAST: Clearly has text (350.6 words/page)
#    ⚡ FAST: Clearly has text (327.6 words/page)
#    ⚡ FAST: Clearly has text (539.8 words/page)
#    ⚡ FAST: Clearly has text (794.2 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (780.2 words/page)
#    ⚡ FAST: Clearly has text (592.0 words/page)
#    ⚡ FAST: Clearly has text (315.4 words/page)
#    ⚡ FAST: Clearly has text (878.6 words/page)
#    ⚡ FAST: Clearly has text (416.0 words/page)
#    ⚡ FAST: Clearly has text (602.6 words/page)
#    ⚡ FAST: Clearly has text (504.8 words/page)
#    ⚡ FAST: Clearly has text (455.8 words/page)
#    ⚡ FAST: Clearly has text (422.6 words/page)
#    ⚡ FAST: Clearly has text (464.8 words/page)
#    ⚡ FAST: Clearly has text (485.6 words/page)
#    ⚡ FAST: Clearly has text (227.2 words/page)
#    ⚡ FAST: Clearly has text (335.4 words/page)
#    ⚡ FAST: Clearly has text (485.0 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (471.0 words/page)
#    ⚡ FAST: Clearly has text (489.4 words/page)
#    ⚡ FAST: Clearly has text (348.0 words/page)
#    ⚡ FAST: Clearly has text (498.8 words/page)
#    ⚡ FAST: Clearly has text (289.6 words/page)
#    ⚡ FAST: Clearly has text (600.8 words/page)
#    ⚡ FAST: Clearly has text (477.2 words/page)
#    ⚡ FAST: Clearly has text (462.0 words/page)
#    ⚡ FAST: Clearly has text (575.8 words/page)
#    ⚡ FAST: Clearly has text (839.3 words/page)
#    ⚡ FAST: Clearly has text (819.4 words/page)
#    ⚡ FAST: Clearly has text (481.2 words/page)
#    ⚡ FAST: Clearly has text (482.8 words/page)
#    ⚡ FAST: Clearly image-only (1.0 words/page)
#    📊 Progress: 900/3049 folders...
#    ⚡ FAST: Clearly has text (614.8 words/page)
#    ⚡ FAST: Clearly has text (270.4 words/page)
#    ⚡ FAST: Clearly has text (552.0 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (591.2 words/page)
#    ⚡ FAST: Clearly has text (323.4 words/page)
#    ⚡ FAST: Clearly has text (661.8 words/page)
#    ⚡ FAST: Clearly has text (421.0 words/page)
#    ⚡ FAST: Clearly has text (195.2 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (592.8 words/page)
#    ⚡ FAST: Clearly has text (415.8 words/page)
#    ⚡ FAST: Clearly has text (557.4 words/page)
#    ⚡ FAST: Clearly has text (446.2 words/page)
#    ⚡ FAST: Clearly has text (474.0 words/page)
#    ⚡ FAST: Clearly has text (480.0 words/page)
#    ⚡ FAST: Clearly has text (346.6 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (418.0 words/page)
#    ⚡ FAST: Clearly has text (545.0 words/page)
#    ⚡ FAST: Clearly has text (166.4 words/page)
#    ⚡ FAST: Clearly has text (918.4 words/page)
#    ⚡ FAST: Clearly has text (446.2 words/page)
#    ⚡ FAST: Clearly has text (528.0 words/page)
#    ⚡ FAST: Clearly has text (305.8 words/page)
#    ⚡ FAST: Clearly has text (551.8 words/page)
#    ⚡ FAST: Clearly has text (670.8 words/page)
#    ⚡ FAST: Clearly has text (575.0 words/page)
#    ⚡ FAST: Clearly has text (477.0 words/page)
#    ⚡ FAST: Clearly has text (443.6 words/page)
#    ⚡ FAST: Clearly has text (304.2 words/page)
#    ⚡ FAST: Clearly has text (460.0 words/page)
#    ⚡ FAST: Clearly has text (299.2 words/page)
#    ⚡ FAST: Clearly has text (428.4 words/page)
#    ⚡ FAST: Clearly has text (370.6 words/page)
#    ⚡ FAST: Clearly has text (652.2 words/page)
#    ⚡ FAST: Clearly has text (306.8 words/page)
#    🔍 BORDERLINE: Verifying with PDFMiner (24.3 words/page)...
#    🔍 PDFMiner verification...
#       ⚠️  PDFMiner: Minimal text (24.0 words/page)
#    ⚡ FAST: Clearly has text (482.8 words/page)
#    ⚡ FAST: Clearly has text (362.0 words/page)
#    ⚡ FAST: Clearly has text (482.2 words/page)
#    ⚡ FAST: Clearly has text (783.0 words/page)
#    ⚡ FAST: Clearly has text (533.2 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (543.4 words/page)
#    ⚡ FAST: Clearly has text (574.0 words/page)
#    ⚡ FAST: Clearly has text (497.6 words/page)
#    ⚡ FAST: Clearly has text (433.0 words/page)
#    ⚡ FAST: Clearly has text (498.6 words/page)
#    ⚡ FAST: Clearly has text (685.2 words/page)
#    ⚡ FAST: Clearly has text (444.2 words/page)
#    ⚡ FAST: Clearly has text (555.0 words/page)
#    ⚡ FAST: Clearly has text (585.8 words/page)
#    ⚡ FAST: Clearly has text (392.2 words/page)
#    ⚡ FAST: Clearly has text (500.0 words/page)
#    ⚡ FAST: Clearly has text (417.2 words/page)
#    ⚡ FAST: Clearly has text (354.8 words/page)
#    ⚡ FAST: Clearly has text (516.8 words/page)
#    ⚡ FAST: Clearly has text (169.6 words/page)
#    ⚡ FAST: Clearly has text (294.2 words/page)
#    ⚡ FAST: Clearly has text (569.8 words/page)
#    ⚡ FAST: Clearly has text (479.8 words/page)
#    ⚡ FAST: Clearly has text (500.6 words/page)
#    ⚡ FAST: Clearly has text (504.4 words/page)
#    ⚡ FAST: Clearly has text (382.6 words/page)
#    ⚡ FAST: Clearly has text (348.4 words/page)
#    ⚡ FAST: Clearly has text (451.0 words/page)
#    ⚡ FAST: Clearly has text (440.8 words/page)
#    ⚡ FAST: Clearly has text (686.2 words/page)
#    ⚡ FAST: Clearly has text (588.6 words/page)
#    ⚡ FAST: Clearly has text (516.0 words/page)
#    ⚡ FAST: Clearly has text (349.0 words/page)
#    ⚡ FAST: Clearly has text (540.8 words/page)
#    📊 Progress: 1000/3049 folders...
#    ⚡ FAST: Clearly has text (514.0 words/page)
#    ⚡ FAST: Clearly has text (423.6 words/page)
#    ⚡ FAST: Clearly has text (350.0 words/page)
#    ⚡ FAST: Clearly has text (383.2 words/page)
#    ⚡ FAST: Clearly has text (376.8 words/page)
#    ⚡ FAST: Clearly has text (449.0 words/page)
#    ⚡ FAST: Clearly has text (515.6 words/page)
#    ⚡ FAST: Clearly has text (454.0 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (430.8 words/page)
#    ⚡ FAST: Clearly has text (434.6 words/page)
#    ⚡ FAST: Clearly has text (464.4 words/page)
#    ⚡ FAST: Clearly has text (353.8 words/page)
#    ⚡ FAST: Clearly has text (410.0 words/page)
#    ⚡ FAST: Clearly image-only (4.8 words/page)
#    ⚡ FAST: Clearly has text (456.0 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (260.8 words/page)
#    ⚡ FAST: Clearly has text (182.6 words/page)
#    ⚡ FAST: Clearly has text (206.4 words/page)
#    ⚡ FAST: Clearly has text (545.2 words/page)
#    ⚡ FAST: Clearly has text (430.0 words/page)
#    ⚡ FAST: Clearly has text (418.4 words/page)
#    ⚡ FAST: Clearly has text (442.0 words/page)
#    ⚡ FAST: Clearly has text (232.0 words/page)
#    ⚡ FAST: Clearly has text (193.0 words/page)
#    ⚡ FAST: Clearly has text (337.0 words/page)
#    ⚡ FAST: Clearly has text (491.2 words/page)
#    ⚡ FAST: Clearly has text (310.4 words/page)
#    ⚡ FAST: Clearly has text (574.4 words/page)
#    ⚡ FAST: Clearly has text (429.6 words/page)
#    ⚡ FAST: Clearly has text (312.0 words/page)
#    ⚡ FAST: Clearly has text (602.0 words/page)
#    ⚡ FAST: Clearly has text (351.4 words/page)
#    ⚡ FAST: Clearly has text (440.4 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (558.4 words/page)
#    ⚡ FAST: Clearly has text (132.8 words/page)
#    ⚡ FAST: Clearly has text (600.6 words/page)
#    ⚡ FAST: Clearly has text (562.2 words/page)
#    ⚡ FAST: Clearly has text (453.6 words/page)
#    ⚡ FAST: Clearly has text (387.6 words/page)
#    ⚡ FAST: Clearly has text (529.0 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (477.4 words/page)
#    ⚡ FAST: Clearly has text (601.0 words/page)
#    ⚡ FAST: Clearly has text (880.8 words/page)
#    ⚡ FAST: Clearly has text (391.4 words/page)
#    ⚡ FAST: Clearly has text (703.4 words/page)
#    ⚡ FAST: Clearly has text (311.5 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (346.2 words/page)
#    ⚡ FAST: Clearly has text (515.0 words/page)
#    ⚡ FAST: Clearly has text (309.4 words/page)
#    ⚡ FAST: Clearly has text (303.6 words/page)
#    ⚡ FAST: Clearly has text (447.2 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (404.4 words/page)
#    ⚡ FAST: Clearly has text (511.4 words/page)
#    ⚡ FAST: Clearly has text (318.2 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (359.4 words/page)
#    ⚡ FAST: Clearly has text (117.0 words/page)
#    ⚡ FAST: Clearly has text (485.6 words/page)
#    ⚡ FAST: Clearly has text (415.4 words/page)
#    ⚡ FAST: Clearly has text (317.2 words/page)
#    ⚡ FAST: Clearly has text (439.4 words/page)
#    📊 Progress: 1100/3049 folders...
#    ⚡ FAST: Clearly has text (727.5 words/page)
#    ⚡ FAST: Clearly has text (478.8 words/page)
#    ⚡ FAST: Clearly has text (510.2 words/page)
#    ⚡ FAST: Clearly has text (322.6 words/page)
#    ⚡ FAST: Clearly has text (543.0 words/page)
#    ⚡ FAST: Clearly has text (475.6 words/page)
#    ⚡ FAST: Clearly has text (393.0 words/page)
#    ⚡ FAST: Clearly has text (502.8 words/page)
#    ⚡ FAST: Clearly has text (487.2 words/page)
#    ⚡ FAST: Clearly has text (631.6 words/page)
#    ⚡ FAST: Clearly has text (432.8 words/page)
#    ⚡ FAST: Clearly has text (510.4 words/page)
#    🔍 BORDERLINE: Verifying with PDFMiner (35.5 words/page)...
#    🔍 PDFMiner verification...
#       ✅ PDFMiner confirms: 655 words, 163.8 words/page
#    ⚡ FAST: Clearly has text (281.4 words/page)
#    ⚡ FAST: Clearly has text (599.6 words/page)
#    🔍 BORDERLINE: Verifying with PDFMiner (17.0 words/page)...
#    🔍 PDFMiner verification...
#       ⚠️  PDFMiner: Minimal text (22.5 words/page)
#    ⚡ FAST: Clearly has text (212.0 words/page)
#    ⚡ FAST: Clearly has text (543.8 words/page)
#    ⚡ FAST: Clearly has text (485.0 words/page)
#    ⚡ FAST: Clearly has text (283.2 words/page)
#    ⚡ FAST: Clearly has text (551.6 words/page)
#    ⚡ FAST: Clearly has text (513.4 words/page)
#    ⚡ FAST: Clearly has text (398.5 words/page)
#    ⚡ FAST: Clearly has text (534.0 words/page)
#    ⚡ FAST: Clearly has text (532.8 words/page)
#    ⚡ FAST: Clearly has text (396.6 words/page)
#    ⚡ FAST: Clearly has text (674.2 words/page)
#    ⚡ FAST: Clearly has text (255.0 words/page)
#    ⚡ FAST: Clearly has text (405.4 words/page)
#    ⚡ FAST: Clearly has text (270.5 words/page)
#    ⚡ FAST: Clearly has text (483.0 words/page)
#    ⚡ FAST: Clearly has text (405.6 words/page)
#    ⚡ FAST: Clearly has text (507.2 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (757.6 words/page)
#    ⚡ FAST: Clearly has text (221.6 words/page)
#    ⚡ FAST: Clearly has text (525.4 words/page)
#    ⚡ FAST: Clearly has text (393.6 words/page)
#    ⚡ FAST: Clearly has text (465.0 words/page)
#    ⚡ FAST: Clearly has text (362.0 words/page)
#    ⚡ FAST: Clearly has text (542.6 words/page)
#    ⚡ FAST: Clearly has text (356.4 words/page)
#    ⚡ FAST: Clearly has text (329.4 words/page)
#    ⚡ FAST: Clearly has text (587.0 words/page)
#    ⚡ FAST: Clearly has text (394.4 words/page)
#    ⚡ FAST: Clearly has text (161.4 words/page)
#    ⚡ FAST: Clearly has text (266.2 words/page)
#    ⚡ FAST: Clearly has text (274.2 words/page)
#    ⚡ FAST: Clearly has text (433.0 words/page)
#    ⚡ FAST: Clearly has text (366.4 words/page)
#    ⚡ FAST: Clearly has text (505.4 words/page)
#    ⚡ FAST: Clearly has text (430.8 words/page)
#    ⚡ FAST: Clearly has text (576.4 words/page)
#    ⚡ FAST: Clearly has text (478.2 words/page)
#    ⚡ FAST: Clearly has text (330.0 words/page)
#    ⚡ FAST: Clearly image-only (1.0 words/page)
#    ⚡ FAST: Clearly has text (458.0 words/page)
#    ⚡ FAST: Clearly has text (241.6 words/page)
#    ⚡ FAST: Clearly has text (558.8 words/page)
#    ⚡ FAST: Clearly has text (492.8 words/page)
#    ⚡ FAST: Clearly has text (477.4 words/page)
#    ⚡ FAST: Clearly has text (415.6 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (779.0 words/page)
#    ⚡ FAST: Clearly has text (379.8 words/page)
#    🔍 BORDERLINE: Verifying with PDFMiner (31.0 words/page)...
#    🔍 PDFMiner verification...
#       ✅ PDFMiner confirms: 101 words, 50.5 words/page
#    ⚡ FAST: Clearly has text (370.4 words/page)
#    ⚡ FAST: Clearly has text (200.4 words/page)
#    ⚡ FAST: Clearly has text (168.2 words/page)
#    ⚡ FAST: Clearly has text (516.6 words/page)
#    📊 Progress: 1200/3049 folders...
#    ⚡ FAST: Clearly has text (344.0 words/page)
#    ⚡ FAST: Clearly has text (487.6 words/page)
#    ⚡ FAST: Clearly image-only (1.0 words/page)
#    ⚡ FAST: Clearly has text (362.0 words/page)
#    ⚡ FAST: Clearly has text (309.6 words/page)
#    ⚡ FAST: Clearly has text (481.0 words/page)
#    ⚡ FAST: Clearly has text (552.2 words/page)
#    🔍 BORDERLINE: Verifying with PDFMiner (58.0 words/page)...
#    🔍 PDFMiner verification...
#       ✅ PDFMiner confirms: 1079 words, 359.7 words/page
#    ⚡ FAST: Clearly has text (461.0 words/page)
#    ⚡ FAST: Clearly has text (601.6 words/page)
#    ⚡ FAST: Clearly has text (296.2 words/page)
#    ⚡ FAST: Clearly has text (454.2 words/page)
#    ⚡ FAST: Clearly has text (424.8 words/page)
#    ⚡ FAST: Clearly has text (520.0 words/page)
#    ⚡ FAST: Clearly has text (414.6 words/page)
#    ⚡ FAST: Clearly has text (397.8 words/page)
#    ⚡ FAST: Clearly has text (501.8 words/page)
#    ⚡ FAST: Clearly has text (460.4 words/page)
#    ⚡ FAST: Clearly has text (611.0 words/page)
#    ⚡ FAST: Clearly has text (369.7 words/page)
#    ⚡ FAST: Clearly has text (507.4 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (505.8 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (493.2 words/page)
#    ⚡ FAST: Clearly has text (902.0 words/page)
#    ⚡ FAST: Clearly has text (375.0 words/page)
#    ⚡ FAST: Clearly has text (341.8 words/page)
#    ⚡ FAST: Clearly has text (303.8 words/page)
#    ⚡ FAST: Clearly has text (456.0 words/page)
#    ⚡ FAST: Clearly has text (364.2 words/page)
#    ⚡ FAST: Clearly has text (479.0 words/page)
#    ⚡ FAST: Clearly has text (430.4 words/page)
#    ⚡ FAST: Clearly has text (435.0 words/page)
#    ⚡ FAST: Clearly has text (526.0 words/page)
#    ⚡ FAST: Clearly has text (474.4 words/page)
#    ⚡ FAST: Clearly has text (538.2 words/page)
#    ⚡ FAST: Clearly has text (372.8 words/page)
#    ⚡ FAST: Clearly has text (480.0 words/page)
#    ⚡ FAST: Clearly has text (444.4 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (395.8 words/page)
#    ⚡ FAST: Clearly has text (494.6 words/page)
#    ⚡ FAST: Clearly has text (380.6 words/page)
#    ⚡ FAST: Clearly has text (449.2 words/page)
#    ⚡ FAST: Clearly has text (826.2 words/page)
#    ⚡ FAST: Clearly has text (482.8 words/page)
#    ⚡ FAST: Clearly has text (681.0 words/page)
#    ⚡ FAST: Clearly has text (433.2 words/page)
#    ⚡ FAST: Clearly has text (583.8 words/page)
#    ⚡ FAST: Clearly has text (610.2 words/page)
#    ⚡ FAST: Clearly has text (460.8 words/page)
#    ⚡ FAST: Clearly has text (457.2 words/page)
#    ⚡ FAST: Clearly has text (188.5 words/page)
#    ⚡ FAST: Clearly has text (636.0 words/page)
#    ⚡ FAST: Clearly has text (669.8 words/page)
#    ⚡ FAST: Clearly has text (554.2 words/page)
#    ⚡ FAST: Clearly has text (347.8 words/page)
#    ⚡ FAST: Clearly has text (511.2 words/page)
#    ⚡ FAST: Clearly has text (501.0 words/page)
#    ⚡ FAST: Clearly has text (668.0 words/page)
#    ⚡ FAST: Clearly has text (185.7 words/page)
#    ⚡ FAST: Clearly has text (490.0 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (414.0 words/page)
#    ⚡ FAST: Clearly has text (490.2 words/page)
#    🔍 BORDERLINE: Verifying with PDFMiner (6.6 words/page)...
#    🔍 PDFMiner verification...
#       ⚠️  PDFMiner: Minimal text (1.6 words/page)
#    📊 Progress: 1300/3049 folders...
#    ⚡ FAST: Clearly has text (785.4 words/page)
#    ⚡ FAST: Clearly has text (381.6 words/page)
#    ⚡ FAST: Clearly has text (402.0 words/page)
#    ⚡ FAST: Clearly has text (466.4 words/page)
#    ⚡ FAST: Clearly has text (399.6 words/page)
#    ⚡ FAST: Clearly has text (554.6 words/page)
#    ⚡ FAST: Clearly has text (468.2 words/page)
#    ⚡ FAST: Clearly has text (253.0 words/page)
#    ⚡ FAST: Clearly has text (519.6 words/page)
#    ⚡ FAST: Clearly has text (440.6 words/page)
#    ⚡ FAST: Clearly has text (441.8 words/page)
#    ⚡ FAST: Clearly has text (309.8 words/page)
#    ⚡ FAST: Clearly has text (468.2 words/page)
#    ⚡ FAST: Clearly has text (465.4 words/page)
#    ⚡ FAST: Clearly has text (602.8 words/page)
#    ⚡ FAST: Clearly has text (384.2 words/page)
#    ⚡ FAST: Clearly has text (515.6 words/page)
#    ⚡ FAST: Clearly has text (365.8 words/page)
#    ⚡ FAST: Clearly has text (444.6 words/page)
#    ⚡ FAST: Clearly has text (417.8 words/page)
#    ⚡ FAST: Clearly has text (439.8 words/page)
#    ⚡ FAST: Clearly has text (469.0 words/page)
#    ⚡ FAST: Clearly has text (469.0 words/page)
#    ⚡ FAST: Clearly has text (483.8 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (537.6 words/page)
#    ⚡ FAST: Clearly has text (471.0 words/page)
#    ⚡ FAST: Clearly has text (442.0 words/page)
#    ⚡ FAST: Clearly has text (379.8 words/page)
#    ⚡ FAST: Clearly has text (115.0 words/page)
#    ⚡ FAST: Clearly has text (383.4 words/page)
#    ⚡ FAST: Clearly has text (331.0 words/page)
#    ⚡ FAST: Clearly has text (330.4 words/page)
#    ⚡ FAST: Clearly has text (555.2 words/page)
#    ⚡ FAST: Clearly has text (585.6 words/page)
#    ⚡ FAST: Clearly has text (451.2 words/page)
#    ⚡ FAST: Clearly has text (475.4 words/page)
#    ⚡ FAST: Clearly has text (137.4 words/page)
#    ⚡ FAST: Clearly has text (354.0 words/page)
#    🔍 BORDERLINE: Verifying with PDFMiner (55.0 words/page)...
#    🔍 PDFMiner verification...
#       ✅ PDFMiner confirms: 1090 words, 363.3 words/page
#    🔍 BORDERLINE: Verifying with PDFMiner (25.4 words/page)...
#    🔍 PDFMiner verification...
#       ✅ PDFMiner confirms: 843 words, 140.5 words/page
#    ⚡ FAST: Clearly has text (519.4 words/page)
#    ⚡ FAST: Clearly has text (518.2 words/page)
#    ⚡ FAST: Clearly has text (192.4 words/page)
#    ⚡ FAST: Clearly has text (505.4 words/page)
#    ⚡ FAST: Clearly has text (509.2 words/page)
#    ⚡ FAST: Clearly has text (509.2 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (469.5 words/page)
#    🔍 BORDERLINE: Verifying with PDFMiner (32.6 words/page)...
#    🔍 PDFMiner verification...
#       ✅ PDFMiner confirms: 843 words, 140.5 words/page
#    ⚡ FAST: Clearly has text (519.8 words/page)
#    ⚡ FAST: Clearly has text (339.6 words/page)
#    ⚡ FAST: Clearly has text (563.8 words/page)
#    ⚡ FAST: Clearly has text (509.8 words/page)
#    ⚡ FAST: Clearly has text (481.6 words/page)
#    ⚡ FAST: Clearly has text (513.0 words/page)
#    ⚡ FAST: Clearly has text (434.0 words/page)
#    ⚡ FAST: Clearly has text (438.2 words/page)
#    ⚡ FAST: Clearly has text (573.2 words/page)
#    ⚡ FAST: Clearly has text (365.8 words/page)
#    ⚡ FAST: Clearly has text (355.8 words/page)
#    ⚡ FAST: Clearly has text (210.7 words/page)
#    📊 Progress: 1400/3049 folders...
#    ⚡ FAST: Clearly has text (586.0 words/page)
#    ⚡ FAST: Clearly has text (451.4 words/page)
#    ⚡ FAST: Clearly has text (351.4 words/page)
#    ⚡ FAST: Clearly has text (590.0 words/page)
#    ⚡ FAST: Clearly has text (517.8 words/page)
#    ⚡ FAST: Clearly has text (579.8 words/page)
#    ⚡ FAST: Clearly has text (471.0 words/page)
#    ⚡ FAST: No text detected
# ...
#    ⚡ FAST: Clearly has text (559.2 words/page)
#    ⚡ FAST: Clearly has text (385.6 words/page)
#    ⚡ FAST: Clearly has text (444.4 words/page)
#    📊 Progress: 2600/3049 folders...
#    ⚡ FAST: Clearly has text (527.6 words/page)
#    ⚡ FAST: Clearly has text (463.2 words/page)
#    ⚡ FAST: Clearly has text (536.0 words/page)
#    ⚡ FAST: Clearly has text (575.6 words/page)
#    ⚡ FAST: Clearly has text (873.2 words/page)
#    ⚡ FAST: Clearly has text (371.5 words/page)
#    ⚡ FAST: Clearly has text (455.2 words/page)
#    ⚡ FAST: Clearly has text (407.8 words/page)
#    ⚡ FAST: Clearly has text (298.4 words/page)
#    ⚡ FAST: Clearly has text (568.4 words/page)
#    ⚡ FAST: Clearly has text (501.2 words/page)
#    ⚡ FAST: Clearly has text (519.6 words/page)
#    ⚡ FAST: Clearly has text (175.0 words/page)
#    ⚡ FAST: Clearly has text (384.7 words/page)
#    ⚡ FAST: Clearly has text (481.8 words/page)
#    ⚡ FAST: Clearly has text (478.0 words/page)
#    🔍 BORDERLINE: Verifying with PDFMiner (75.2 words/page)...
#    🔍 PDFMiner verification...
#       ✅ PDFMiner confirms: 512 words, 85.3 words/page
#    ⚡ FAST: Clearly has text (441.2 words/page)
#    ⚡ FAST: Clearly has text (583.4 words/page)
#    ⚡ FAST: Clearly has text (311.4 words/page)
#    ⚡ FAST: Clearly has text (479.4 words/page)
# MuPDF error: format error: No default Layer config
#
#    ⚡ FAST: Clearly has text (487.6 words/page)
#    ⚡ FAST: Clearly has text (548.0 words/page)
#    ⚡ FAST: Clearly has text (414.0 words/page)
#    ⚡ FAST: Clearly has text (457.4 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (379.8 words/page)
#    ⚡ FAST: Clearly has text (412.5 words/page)
#    🔍 BORDERLINE: Verifying with PDFMiner (67.4 words/page)...
#    🔍 PDFMiner verification...
#       ✅ PDFMiner confirms: 843 words, 140.5 words/page
#    ⚡ FAST: Clearly has text (509.5 words/page)
#    ⚡ FAST: Clearly has text (372.4 words/page)
#    ⚡ FAST: Clearly has text (354.8 words/page)
#    🔍 BORDERLINE: Verifying with PDFMiner (29.0 words/page)...
#    🔍 PDFMiner verification...
#       ⚠️  PDFMiner: Minimal text (40.0 words/page)
#    ⚡ FAST: Clearly has text (563.0 words/page)
#    ⚡ FAST: Clearly has text (591.4 words/page)
#    ⚡ FAST: Clearly has text (415.8 words/page)
#    ⚡ FAST: Clearly has text (109.4 words/page)
#    ⚡ FAST: Clearly has text (146.8 words/page)
#    ⚡ FAST: Clearly has text (606.4 words/page)
#    ⚡ FAST: Clearly has text (443.2 words/page)
#    ⚡ FAST: Clearly has text (506.8 words/page)
#    ⚡ FAST: Clearly has text (339.8 words/page)
#    ⚡ FAST: Clearly has text (526.2 words/page)
#    ⚡ FAST: Clearly has text (577.2 words/page)
#    ⚡ FAST: Clearly has text (730.0 words/page)
#    ⚡ FAST: Clearly has text (374.0 words/page)
#    ⚡ FAST: Clearly has text (579.4 words/page)
#    ⚡ FAST: Clearly has text (431.0 words/page)
#    ⚡ FAST: Clearly has text (450.2 words/page)
#    ⚡ FAST: Clearly has text (499.6 words/page)
#    ⚡ FAST: Clearly has text (394.0 words/page)
#    ⚡ FAST: Clearly has text (511.4 words/page)
#    ⚡ FAST: Clearly has text (450.8 words/page)
#    ⚡ FAST: Clearly has text (400.8 words/page)
#    ⚡ FAST: Clearly has text (432.6 words/page)
#    ⚡ FAST: Clearly has text (528.6 words/page)
#    ⚡ FAST: Clearly has text (614.8 words/page)
#    ⚡ FAST: Clearly has text (610.0 words/page)
#    ⚡ FAST: Clearly has text (629.0 words/page)
#    ⚡ FAST: Clearly has text (445.0 words/page)
#    ⚡ FAST: Clearly has text (407.6 words/page)
#    ⚡ FAST: Clearly has text (363.2 words/page)
#    ⚡ FAST: Clearly has text (541.0 words/page)
#    ⚡ FAST: Clearly has text (349.8 words/page)
#    ⚡ FAST: Clearly has text (383.0 words/page)
#    ⚡ FAST: Clearly has text (348.6 words/page)
#    ⚡ FAST: Clearly has text (480.8 words/page)
#    📊 Progress: 2700/3049 folders...
#    ⚡ FAST: Clearly has text (556.4 words/page)
#    ⚡ FAST: Clearly has text (286.8 words/page)
#    ⚡ FAST: Clearly has text (511.8 words/page)
#    ⚡ FAST: Clearly has text (335.6 words/page)
#    ⚡ FAST: Clearly has text (864.8 words/page)
#    ⚡ FAST: Clearly has text (498.8 words/page)
#    ⚡ FAST: Clearly has text (935.8 words/page)
#    ⚡ FAST: Clearly has text (362.4 words/page)
#    ⚡ FAST: Clearly has text (435.6 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (376.0 words/page)
#    ⚡ FAST: Clearly has text (290.0 words/page)
#    ⚡ FAST: Clearly has text (417.6 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (332.0 words/page)
#    ⚡ FAST: Clearly has text (297.6 words/page)
#    ⚡ FAST: Clearly has text (343.8 words/page)
#    ⚡ FAST: Clearly has text (359.2 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (334.0 words/page)
#    ⚡ FAST: Clearly has text (439.8 words/page)
#    ⚡ FAST: Clearly has text (585.6 words/page)
#    ⚡ FAST: Clearly has text (451.4 words/page)
#    ⚡ FAST: Clearly has text (496.6 words/page)
#    🔍 BORDERLINE: Verifying with PDFMiner (44.5 words/page)...
#    🔍 PDFMiner verification...
#       ⚠️  PDFMiner: Minimal text (44.0 words/page)
#    ⚡ FAST: Clearly has text (482.6 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (418.2 words/page)
#    🔍 BORDERLINE: Verifying with PDFMiner (17.2 words/page)...
#    🔍 PDFMiner verification...
#       ⚠️  PDFMiner: Minimal text (13.9 words/page)
#    ⚡ FAST: Clearly has text (443.2 words/page)
#    ⚡ FAST: Clearly has text (477.4 words/page)
#    ⚡ FAST: Clearly has text (550.0 words/page)
#    ⚡ FAST: Clearly has text (593.2 words/page)
#    ⚡ FAST: Clearly has text (839.0 words/page)
#    ⚡ FAST: Clearly has text (470.0 words/page)
#    ⚡ FAST: Clearly has text (357.2 words/page)
#    ⚡ FAST: Clearly has text (388.0 words/page)
#    ⚡ FAST: Clearly has text (522.0 words/page)
#    ⚡ FAST: Clearly has text (298.2 words/page)
#    ⚡ FAST: Clearly has text (485.0 words/page)
#    ⚡ FAST: Clearly has text (332.2 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (798.2 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (873.2 words/page)
#    ⚡ FAST: Clearly has text (476.0 words/page)
#    ⚡ FAST: Clearly has text (363.8 words/page)
#    ⚡ FAST: Clearly has text (509.0 words/page)
#    ⚡ FAST: Clearly has text (279.6 words/page)
#    ⚡ FAST: Clearly has text (459.6 words/page)
#    ⚡ FAST: Clearly has text (180.4 words/page)
#    ⚡ FAST: Clearly has text (469.2 words/page)
#    ⚡ FAST: Clearly has text (565.6 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (374.8 words/page)
#    ⚡ FAST: Clearly has text (325.4 words/page)
#    ⚡ FAST: Clearly has text (393.5 words/page)
#    ⚡ FAST: Clearly has text (503.2 words/page)
#    ⚡ FAST: Clearly has text (219.2 words/page)
#    ⚡ FAST: Clearly has text (451.0 words/page)
#    ⚡ FAST: Clearly has text (355.4 words/page)
#    ⚡ FAST: Clearly has text (429.2 words/page)
#    ⚡ FAST: Clearly has text (438.2 words/page)
#    ⚡ FAST: Clearly has text (247.2 words/page)
#    ⚡ FAST: Clearly has text (438.8 words/page)
#    ⚡ FAST: Clearly has text (367.6 words/page)
#    ⚡ FAST: Clearly has text (537.6 words/page)
#    ⚡ FAST: Clearly has text (480.6 words/page)
#    ⚡ FAST: Clearly has text (399.0 words/page)
#    ⚡ FAST: Clearly has text (419.0 words/page)
#    ⚡ FAST: Clearly has text (337.2 words/page)
#    ⚡ FAST: Clearly has text (250.6 words/page)
#    ⚡ FAST: Clearly has text (400.6 words/page)
#    ⚡ FAST: Clearly has text (431.4 words/page)
#    ⚡ FAST: Clearly has text (382.2 words/page)
#    ⚡ FAST: Clearly has text (501.2 words/page)
#    ⚡ FAST: Clearly has text (346.0 words/page)
#    ⚡ FAST: Clearly has text (296.8 words/page)
#    📊 Progress: 2800/3049 folders...
#    ⚡ FAST: Clearly has text (826.0 words/page)
#    ⚡ FAST: Clearly has text (457.6 words/page)
#    ⚡ FAST: Clearly has text (187.2 words/page)
#    ⚡ FAST: Clearly has text (413.4 words/page)
#    ⚡ FAST: Clearly has text (390.4 words/page)
#    ⚡ FAST: Clearly has text (549.6 words/page)
#    ⚡ FAST: Clearly has text (618.0 words/page)
#    ⚡ FAST: Clearly has text (319.7 words/page)
#    ⚡ FAST: Clearly has text (478.6 words/page)
#    🔍 BORDERLINE: Verifying with PDFMiner (47.3 words/page)...
#    🔍 PDFMiner verification...
#       ✅ PDFMiner confirms: 179 words, 59.7 words/page
#    ⚡ FAST: Clearly has text (356.3 words/page)
#    ⚡ FAST: Clearly has text (537.8 words/page)
#    ⚡ FAST: Clearly has text (329.2 words/page)
#    ⚡ FAST: Clearly has text (417.6 words/page)
#    ⚡ FAST: Clearly has text (583.2 words/page)
#    ⚡ FAST: Clearly has text (560.8 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (513.0 words/page)
#    ⚡ FAST: Clearly has text (441.8 words/page)
#    ⚡ FAST: Clearly has text (386.2 words/page)
#    ⚡ FAST: Clearly has text (465.0 words/page)
#    ⚡ FAST: Clearly has text (305.0 words/page)
#    ⚡ FAST: Clearly has text (469.2 words/page)
#    ⚡ FAST: Clearly has text (485.4 words/page)
#    ⚡ FAST: Clearly has text (545.4 words/page)
#    ⚡ FAST: Clearly has text (352.8 words/page)
#    ⚡ FAST: Clearly has text (342.2 words/page)
#    ⚡ FAST: Clearly has text (457.6 words/page)
#    ⚡ FAST: Clearly has text (262.6 words/page)
#    ⚡ FAST: Clearly has text (190.3 words/page)
#    ⚡ FAST: Clearly has text (508.8 words/page)
#    ⚡ FAST: Clearly has text (375.8 words/page)
#    ⚡ FAST: Clearly has text (377.2 words/page)
#    ⚡ FAST: Clearly has text (464.2 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (270.8 words/page)
#    ⚡ FAST: Clearly has text (477.2 words/page)
#    ⚡ FAST: Clearly has text (493.8 words/page)
#    ⚡ FAST: Clearly has text (582.0 words/page)
#    ⚡ FAST: Clearly has text (548.6 words/page)
#    ⚡ FAST: Clearly has text (437.8 words/page)
#    ⚡ FAST: Clearly has text (473.0 words/page)
#    ⚡ FAST: Clearly has text (543.0 words/page)
#    ⚡ FAST: Clearly has text (513.6 words/page)
#    ⚡ FAST: Clearly has text (487.0 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (548.2 words/page)
#    ⚡ FAST: Clearly has text (417.0 words/page)
#    🔍 BORDERLINE: Verifying with PDFMiner (47.0 words/page)...
#    🔍 PDFMiner verification...
#       ⚠️  PDFMiner: Minimal text (24.4 words/page)
#    ⚡ FAST: Clearly has text (350.8 words/page)
#    ⚡ FAST: Clearly has text (465.6 words/page)
#    ⚡ FAST: Clearly has text (462.2 words/page)
#    ⚡ FAST: Clearly has text (511.8 words/page)
#    ⚡ FAST: Clearly has text (710.4 words/page)
#    ⚡ FAST: Clearly has text (510.6 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (336.8 words/page)
#    ⚡ FAST: Clearly has text (580.2 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (321.0 words/page)
#    ⚡ FAST: Clearly has text (465.4 words/page)
#    ⚡ FAST: Clearly has text (513.2 words/page)
#    ⚡ FAST: Clearly has text (465.6 words/page)
#    ⚡ FAST: Clearly has text (472.8 words/page)
#    ⚡ FAST: Clearly has text (470.4 words/page)
#    ⚡ FAST: Clearly has text (381.2 words/page)
#    ⚡ FAST: Clearly has text (235.0 words/page)
#    📊 Progress: 2900/3049 folders...
#    ⚡ FAST: Clearly has text (361.6 words/page)
#    ⚡ FAST: Clearly has text (418.6 words/page)
#    ⚡ FAST: Clearly has text (451.0 words/page)
#    ⚡ FAST: Clearly has text (434.2 words/page)
#    ⚡ FAST: Clearly has text (505.4 words/page)
#    ⚡ FAST: Clearly has text (582.2 words/page)
#    🔍 BORDERLINE: Verifying with PDFMiner (48.5 words/page)...
#    🔍 PDFMiner verification...
#       ✅ PDFMiner confirms: 1134 words, 283.5 words/page
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (334.3 words/page)
#    ⚡ FAST: Clearly has text (397.0 words/page)
#    ⚡ FAST: Clearly has text (320.0 words/page)
#    ⚡ FAST: Clearly has text (192.8 words/page)
#    ⚡ FAST: Clearly has text (369.2 words/page)
#    ⚡ FAST: Clearly has text (763.0 words/page)
#    ⚡ FAST: Clearly has text (344.2 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (411.0 words/page)
#    ⚡ FAST: Clearly has text (392.4 words/page)
#    ⚡ FAST: Clearly has text (499.6 words/page)
#    ⚡ FAST: Clearly has text (373.0 words/page)
#    ⚡ FAST: Clearly has text (594.8 words/page)
#    ⚡ FAST: Clearly has text (345.8 words/page)
#    ⚡ FAST: Clearly has text (400.6 words/page)
#    ⚡ FAST: Clearly has text (275.4 words/page)
#    ⚡ FAST: Clearly has text (434.8 words/page)
#    ⚡ FAST: Clearly has text (616.2 words/page)
#    ⚡ FAST: Clearly has text (385.6 words/page)
#    ⚡ FAST: Clearly has text (273.3 words/page)
#    ⚡ FAST: Clearly has text (583.2 words/page)
#    ⚡ FAST: Clearly has text (465.8 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (457.6 words/page)
#    ⚡ FAST: Clearly has text (478.0 words/page)
#    ⚡ FAST: Clearly has text (548.8 words/page)
#    ⚡ FAST: Clearly has text (521.8 words/page)
#    ⚡ FAST: Clearly has text (584.0 words/page)
#    ⚡ FAST: Clearly has text (457.0 words/page)
#    ⚡ FAST: Clearly has text (450.8 words/page)
#    ⚡ FAST: Clearly has text (514.0 words/page)
#    ⚡ FAST: Clearly has text (362.8 words/page)
#    ⚡ FAST: Clearly has text (567.8 words/page)
#    ⚡ FAST: Clearly has text (594.0 words/page)
#    ⚡ FAST: Clearly has text (136.8 words/page)
#    ⚡ FAST: Clearly has text (465.0 words/page)
#    ⚡ FAST: Clearly has text (521.6 words/page)
#    ⚡ FAST: Clearly has text (272.0 words/page)
#    ⚡ FAST: Clearly has text (550.8 words/page)
#    ⚡ FAST: Clearly has text (420.0 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (780.8 words/page)
#    ⚡ FAST: Clearly has text (575.6 words/page)
#    ⚡ FAST: Clearly has text (1043.2 words/page)
#    ⚡ FAST: Clearly has text (566.6 words/page)
#    ⚡ FAST: Clearly has text (468.4 words/page)
#    ⚡ FAST: Clearly has text (378.0 words/page)
#    ⚡ FAST: Clearly has text (464.4 words/page)
#    ⚡ FAST: Clearly has text (339.4 words/page)
#    ⚡ FAST: Clearly has text (276.0 words/page)
#    ⚡ FAST: Clearly has text (367.2 words/page)
#    ⚡ FAST: Clearly has text (345.2 words/page)
#    ⚡ FAST: Clearly has text (460.2 words/page)
#    ⚡ FAST: Clearly has text (532.8 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (331.0 words/page)
#    ⚡ FAST: Clearly has text (301.0 words/page)
#    📊 Progress: 3000/3049 folders...
#    ⚡ FAST: Clearly has text (919.0 words/page)
#    ⚡ FAST: Clearly has text (486.6 words/page)
#    ⚡ FAST: Clearly has text (422.6 words/page)
#    ⚡ FAST: Clearly has text (401.2 words/page)
#    ⚡ FAST: Clearly has text (413.0 words/page)
#    ⚡ FAST: Clearly has text (279.0 words/page)
#    ⚡ FAST: Clearly has text (389.8 words/page)
#    ⚡ FAST: Clearly has text (549.6 words/page)
#    ⚡ FAST: Clearly has text (718.6 words/page)
#    ⚡ FAST: Clearly has text (202.0 words/page)
#    ⚡ FAST: Clearly has text (354.0 words/page)
#    ⚡ FAST: Clearly has text (495.6 words/page)
#    ⚡ FAST: No text detected
#    ⚡ FAST: Clearly has text (351.5 words/page)
#    🔍 BORDERLINE: Verifying with PDFMiner (6.2 words/page)...
#    🔍 PDFMiner verification...
#       ⚠️  PDFMiner: Minimal text (24.9 words/page)
#    ⚡ FAST: Clearly has text (498.6 words/page)
#    ⚡ FAST: Clearly has text (372.4 words/page)
#    ⚡ FAST: Clearly has text (286.0 words/page)
#    ⚡ FAST: Clearly has text (491.6 words/page)
#    ⚡ FAST: Clearly has text (433.0 words/page)
#    ⚡ FAST: Clearly has text (321.6 words/page)
#    ⚡ FAST: Clearly has text (412.4 words/page)
#    ⚡ FAST: Clearly has text (421.4 words/page)
#    ⚡ FAST: Clearly has text (610.0 words/page)
#    ⚡ FAST: Clearly has text (536.5 words/page)
#    ⚡ FAST: Clearly has text (374.3 words/page)
#    ⚡ FAST: Clearly has text (359.2 words/page)
#    ⚡ FAST: Clearly has text (1002.4 words/page)
#    ⚡ FAST: Clearly has text (607.0 words/page)
#    ⚡ FAST: Clearly has text (453.0 words/page)
#    ⚡ FAST: Clearly has text (391.0 words/page)
#    ⚡ FAST: Clearly has text (450.8 words/page)
#    ⚡ FAST: Clearly has text (443.8 words/page)
#    ⚡ FAST: Clearly has text (519.0 words/page)
#    ⚡ FAST: Clearly has text (386.0 words/page)
#    ⚡ FAST: Clearly has text (334.0 words/page)
#
# 📊 SCAN COMPLETE
#    📁 Total folders: 3049
#    📄 Total PDFs found: 2142
#    ✅ PDFs with text: 1976
#    🔍 PDFs needing OCR: 165
#    ❌ Analysis errors: 1
#    📂 Folders with no PDFs: 907
#
# ⏱️  Scan completed in 172.8 seconds
# 📊 Processing rate: 12.4 PDFs per second
# 💾 Raw results saved to: ocr_analysis/storage_scan_results.json

# %%
scan_results = "./ocr_analysis/storage_scan_results.json"
with open(scan_results, "r") as f:
    storage_results = json.load(f)
print(f"📥 Loaded existing scan results from: {scan_results}")
print(f"📊 Found {len(storage_results['needs_ocr'])} PDFs needing OCR")
for item in storage_results["needs_ocr"]:
    print(item)
# Out:
# 📥 Loaded existing scan results from: ./ocr_analysis/storage_scan_results.json
# 📊 Found 165 PDFs needing OCR
# WD7QAWT8
# 3MHUC7ET
# J82TM6Z4
# 9AVIX9QT
# ITQG8UQD
# 93QXHL5F
# 9DEFUPBB
# 9XJ4PIWC
# 8F7FTAYQ
# B4GCAM3M
# PEJDL2B3
# CQDBIS9B
# 8X5UIDYQ
# 6NRLQX8D
# GJC9X2R8
# XAWTQXYS
# UPEMRQ2N
# MCQRDT29
# XVICWEGR
# BF88EXXG
# WFBC8JM2
# ZBH5H6QU
# 479NNEH8
# XZ3XISCU
# IZTFBBPY
# 53T2GUZ3
# NQ7E2N7W
# 9X3K4NSM
# 4BWWCABL
# ZUVZNVA3
# D3AYTM4J
# 56PHA8W7
# AGX42NX7
# RLIR69BL
# 5E48NF8Q
# MD7KBY55
# THBFU9JY
# 5UUME6DT
# EE7VXG84
# I5DHZ9B9
# 8IF4KLRD
# VRNCPXU7
# SHHITQCB
# 7YAGWV36
# EV4ICQST
# Q97TD3RD
# GYFIXBGZ
# 73V38NCM
# 8EN5CRZ4
# KULC6BGQ
# 6227ASQ2
# 7AKR972W
# D2J7HGAY
# QKP67EI3
# 9PLDEPEZ
# I4SY92HM
# MVZAR3EP
# YK3PE754
# QNXW9DBZ
# B9CHN9XR
# BBXHZHVZ
# F9BY6VW3
# XV8JE4XQ
# F2IGQ6ND
# SLTRT7DB
# TN5EITB3
# BNIY6RS4
# B4ZII4VX
# 36QXTIFY
# TJ6NCY5Z
# 85XR9QK8
# XUBEJCTB
# GQZ3KV5R
# ISDW59XD
# D29QI29M
# G5P87E8M
# E7QUBUE3
# S4YPN4RV
# GR3LU674
# 2NSJ2AFB
# LBXY7GVI
# P4RHKKHL
# Q54SLTSI
# PVCTI8ZP
# 3HBMR8NQ
# ZMBZ7N8B
# JG2TS3WB
# T7I848CX
# MLDGR7BT
# RR27EW2V
# UJFI55VP
# VIWEG2SN
# XSNGVWXD
# IZNGKBKT
# WAMZQJUY
# ZLYSZLU5
# UKXE6NSX
# TF65LMGS
# C7PIXBT8
# M722SCS2
# KIPBDJIG
# XWNEY3VS
# 9SM8J6C5
# 6LAGL93T
# ACDKDBP3
# G2VI7RFW
# G4WN2AKA
# T4XQ4QKK
# Z3SZJNF7
# MHQSNLVU
# K954RUH2
# 6T4TWQGD
# K3JLL2GT
# NVW7E9EL
# PCLMXMQU
# TK3AB8KU
# 48TEPDF2
# BPFXLVK2
# JIC38VUU
# WEWRBZKI
# FD6HZ6T7
# E8RWP3FA
# BYACUAXR
# EALDVW3L
# F3PCQRK6
# 365UWQQK
# WQPWABRQ
# ZHJWIHZS
# SGBYINIE
# I5KRH76I
# C7S7MA6R
# PDCABGLE
# HXF89J9M
# V3RT8IFJ
# KQR42N39
# XHN2V337
# EWB5G63T
# 3LUG5H9R
# UWA9IJV8
# R7MVJUWR
# 3LXTWQYH
# LLNU7WJR
# K2QPJSVE
# EF7CTRYN
# CK3DKZGJ
# FFIBP2NA
# S7LUWMCR
# JWZ7SGZE
# CB2R2ZG6
# C6QQX25V
# 27Q8EZ55
# YUW6MMFA
# P8VTJQQT
# IAW7EAPL
# UWCDEBDF
# RIADT9AI
# 3WN3CXKH
# 9JFTEKE3
# 78PPQAIY
# EX6X34ZR
# VZEJ8UNN
# 23WYT9X8
# UK47CPEY
# 6ZYY4MWU
# WK5SPVN4

# %% [markdown]
# ## Generate OCR Task Lists
#
# Create actionable lists of items that need OCR, with optional metadata lookup.

# %%
# My Zotero Checker
import json
import shlex

scan_file = "./ocr_analysis/storage_scan_results.json"
with open(scan_file, "r") as f:
    storage_results = json.load(f)
print("🔍 Getting metadata for items that need OCR...")
ocr_metadata = lookup_zotero_metadata(storage_results["needs_ocr"])

needs_ocr = storage_results["needs_ocr"]
has_text = storage_results["has_text"]
errors = storage_results["errors"]
total_pdfs = storage_results["total_pdfs"]

OCR_DIR = "./ocr_folders"
if not os.path.exists(OCR_DIR):
    os.mkdir(OCR_DIR)

print(f"📚 Total PDFs analyzed: {total_pdfs}")
print(f"✅ PDFs with good text: {len(has_text)} ({len(has_text)/total_pdfs*100:.1f}%)")
print(f"🔍 PDFs needing OCR: {len(needs_ocr)} ({len(needs_ocr)/total_pdfs*100:.1f}%)")
print(f"❌ PDFs with errors: {len(errors)} ({len(errors)/total_pdfs*100:.1f}%)")

csv_lines = []
headers = ["key", "title", "type", "language", "size_mb", "words_per_page", "filename"]

if not Path("./ocr_scripts").exists():
    os.mkdir("./ocr_scripts")

# ...existing code...
with open("./ocr_scripts/ocr_bash.sh", "w") as f:
    f.write("#!/bin/bash\n\n")
    f.write("set -e  # Exit on any error\n")
    f.write("set -u  # Exit on undefined variables\n\n")

    # Progress tracking
    f.write("TOTAL_FILES={}\n".format(len(ocr_metadata.keys())))
    f.write("CURRENT=0\n")
    f.write("SUCCESS=0\n")
    f.write("FAILED=0\n\n")

    log_dir = Path("./ocr_scripts").resolve()
    if not log_dir.exists():
        os.mkdir(log_dir)
    # Log file
    logfile = Path("./ocr_scripts/ocr_log.txt").resolve()
    f.write(f"LOG_FILE={logfile}\n")
    f.write('echo "OCR Processing Started: $(date)" > "$LOG_FILE"\n\n')

    dir = Path("~/Desktop/zotero-storage-copy").expanduser()
    target_dir = Path("./ocr_folders").resolve()

    for idx, item in enumerate(ocr_metadata.items()):
        key, meta = item
        title = meta.get("title", "Unknown Title")
        language = meta.get("language", "unknown")

        if "turc 130" in meta["title"].lower():
            continue

        # Get the ORIGINAL filename from your storage results
        original_filename = [
            f for f in os.listdir(f"{dir}/{key}") if f.endswith(".pdf")
        ][0]
        safe_filename = shlex.quote(original_filename)
        # Clean filename for bash - escape ALL problematic characters
        original_path = f"{dir}/{key}/{original_filename}"
        safe_path = shlex.quote(original_path)

        target_path = f"{target_dir}/{key}/{original_filename}"
        safe_target_path = shlex.quote(target_path)
        # Progress counter
        f.write("CURRENT=$((CURRENT + 1))\n")
        f.write(f"""echo "[$CURRENT/$TOTAL_FILES] Processing {key} - {title}..."\n""")

        # Check if source file exists
        # f.write(f"if [ ! -f {safe_path} ]; then\n")
        # f.write(
        #     f"""    echo "ERROR: Source file not found: {safe_path}" | tee -a "$LOG_FILE"\n"""
        # )
        # f.write(f"    FAILED=$((FAILED + 1))\n")
        # f.write(f"else\n")  # ← ADD THIS
        # f.write(f"""    echo "Found source file: {safe_path}"\n""")
        # f.write(f"fi\n\n")

        # f.write(f"""if [ ! -d "{target_dir}/{key}" ]; then\n""")
        # f.write(f"""    mkdir -p "{target_dir}/{key}"\n""")
        # f.write(f"""    echo "Created target directory: {target_dir}/{key}"\n""")
        # f.write(f"else\n")
        # f.write(f"""    echo "Target directory already exists: {target_dir}/{key}"\n""")
        # f.write(f"fi\n\n")  # ← This closes the if statement properly!
        # # Check if output already exists (skip if exists)
        # f.write(f"""if [ -f {safe_target_path} ]; then\n""")
        # f.write(
        #     f"""    echo "SKIP: Output already exists: {original_filename}" | tee -a "$LOG_FILE"\n"""
        # )
        # f.write(f"    SUCCESS=$((SUCCESS + 1))\n")
        # f.write(f"""else\n""")
        # f.write(f"""    echo "Processing file: {safe_path}"\n""")
        # f.write(f"fi\n\n")

        f.write(f"""cd "{dir}/{key}"\n""")

        # Start timing
        f.write("START_TIME=$(date +%s)\n")

        # Choose language and run OCR with error handling
        if (
            language == "tr"
            or "muhim" in title.lower()
            or "defter" in title.lower()
            or "sefaretnamesi" in title.lower()
        ):
            lang_code = "tur"
        elif language == "fr":
            lang_code = "fra"
        else:
            lang_code = "eng"

        f.write(
            f"""
        source_pdf{idx}=$(find . -name "*.pdf" -type f | head -1)
        source_file{idx}="{dir}/{key}/$source_pdf{idx}"
        target_file{idx}="{target_dir}/{key}/$source_pdf{idx}"
        file_name{idx}="$source_pdf{idx}"
        if [ -z "$source_pdf{idx}" ]; then
            echo "ERROR: Source file not found: $source_file{idx}" | tee -a "$LOG_FILE"
            FAILED=$((FAILED + 1))
        else
            echo "Found source file: $source_file{idx}"
            
            # Create target directory
            if [ ! -d "{target_dir}/{key}" ]; then
                mkdir -p "{target_dir}/{key}"
                echo "Created target directory: {target_dir}/{key}"
            else
                echo "Target directory already exists: {target_dir}/{key}"
            fi
            
            # OCR processing
            if [ -f "$target_file{idx}" ]; then
                echo "SKIP: Output already exists: $file_name{idx}" | tee -a "$LOG_FILE"
                SUCCESS=$((SUCCESS + 1))
            else
                echo "Processing file: $source_file{idx}"
                cd "{dir}/{key}"
                START_TIME=$(date +%s)
                
                if ocrmypdf --rotate-pages --deskew --clean --optimize 3 --force-ocr --oversample 300 --language {lang_code} "$source_file{idx}" "$target_file{idx}"; then
                    END_TIME=$(date +%s)
                    DURATION=$((END_TIME - START_TIME))
                    echo "SUCCESS: $file_name{idx} completed in ${{DURATION}}s" | tee -a "$LOG_FILE"
                    SUCCESS=$((SUCCESS + 1))
                else
                    echo "ERROR: Failed to process $source_file{idx}" | tee -a "$LOG_FILE"
                    FAILED=$((FAILED + 1))
                fi
            fi
        fi

        """
        )
    # Final summary
    f.write("""echo "\\n=== OCR PROCESSING COMPLETE ==="\n""")
    f.write("""echo "Total files: $TOTAL_FILES"\n""")
    f.write("""echo "Successful: $SUCCESS"\n""")
    f.write("""echo "Failed: $FAILED"\n""")
    f.write("""echo "Completion: $(date)"\n""")
    f.write("""echo "\\nProcessing Summary: $(date)" >> "$LOG_FILE"\n""")
    f.write("""echo "Success: $SUCCESS, Failed: $FAILED" >> "$LOG_FILE"\n""")
# ...existing code...
# Out:
# 🔍 Getting metadata for items that need OCR...
# 🔍 Looking up metadata for 165 items...
#    📥 Fetching batch 1/4 (attachments)
#    📥 Fetching batch 2/4 (attachments)
#    📥 Fetching batch 3/4 (attachments)
#    📥 Fetching batch 4/4 (attachments)
#    📚 Fetching 72 parent items...
#    📥 Parent batch 1/2
#    📥 Parent batch 2/2
#    ✅ Retrieved metadata for 136 attachments
#    📚 Retrieved parent metadata for 72 items
# 📚 Total PDFs analyzed: 2142
# ✅ PDFs with good text: 1976 (92.3%)
# 🔍 PDFs needing OCR: 165 (7.7%)
# ❌ PDFs with errors: 1 (0.0%)

# %%
for folder in storage_results["needs_ocr"]:
    l = os.listdir(f"{dir}/{folder}")
    l = [f for f in l if f.lower().endswith(".pdf")]
    if len(l) > 1:
        print(f"⚠️  WARNING: More than one file in {folder} - skipping copy")
        continue

# %%
for i in range(5):
    item = ocr_metadata[needs_ocr[i]]
    print(item)
# Out:
# {'attachment_title': 'Poumarède_2009_Les envoyés ottomans àla cour de France.pdf', 'attachment_type': 'attachment', 'parent_item_key': 'GTPD9ATB', 'filename': 'Poumarède_2009_Les envoyés ottomans àla cour de France.pdf', 'content_type': 'application/pdf', 'date_added': '2019-11-03T17:49:27Z', 'date_modified': '2019-11-03T17:49:28Z', 'title': "Les envoyés ottomans àla cour de France: d'une présence controversée à l'exaltation d'une alliance (XVe-XVIIIe siècles)", 'item_type': 'bookSection', 'language': 'Fench', 'authors': ['Géraud Poumarède'], 'publication_title': '', 'publisher': "Presses de l'Université Paris-Sorbonne", 'date': '2009', 'pages': '63-95', 'volume': '', 'issue': '', 'url': '', 'abstract': ''}
# {'attachment_title': 'Muhimme 51-YOK (1583).pdf', 'attachment_type': 'attachment', 'parent_item_key': '', 'filename': 'Muhimme 51-YOK (1583).pdf', 'content_type': 'application/pdf', 'date_added': '2022-09-29T01:21:29Z', 'date_modified': '2022-09-29T01:21:29Z', 'title': 'Muhimme 51-YOK (1583).pdf', 'item_type': 'attachment', 'language': 'unknown', 'authors': []}
# {'attachment_title': 'Zar-o_Zur_Gold_and_Force_Safavid_Iran_as.pdf', 'attachment_type': 'attachment', 'parent_item_key': '', 'filename': 'Zar-o_Zur_Gold_and_Force_Safavid_Iran_as.pdf', 'content_type': 'application/pdf', 'date_added': '2018-07-20T13:11:01Z', 'date_modified': '2018-07-20T13:11:01Z', 'title': 'Zar-o_Zur_Gold_and_Force_Safavid_Iran_as.pdf', 'item_type': 'attachment', 'language': 'unknown', 'authors': []}
# {'attachment_title': 'Heath - 1986 - Crusading Commonplaces La Noue, Lucinge and Rheto.pdf', 'attachment_type': 'attachment', 'parent_item_key': 'J3M3BSWZ', 'filename': 'Heath - 1986 - Crusading Commonplaces La Noue, Lucinge and Rheto.pdf', 'content_type': 'application/pdf', 'date_added': '2021-05-30T20:46:57Z', 'date_modified': '2021-05-30T20:46:57Z', 'title': 'Crusading Commonplaces: La Noue, Lucinge and Rhetoric against the Turks', 'item_type': 'book', 'language': '', 'authors': ['Michael Heath'], 'publication_title': '', 'publisher': 'Librairie Droz', 'date': '1986', 'pages': '', 'volume': '', 'issue': '', 'url': '', 'abstract': ''}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 2
#       1 for i in range(5):
# ----> 2     item = ocr_metadata[needs_ocr[i]]
#       3     print(item)
#
# KeyError: 'ITQG8UQD'

# %%
len(ocr_metadata.keys())
# Out:
# 164

# %%
# Out:
# d'Arbaleste - 2009 - Escape from the Massacre, 1572.pdf
# Yvelise - 1991 - D'Alexandrie à Istanbul Jean Palerne - Pérégrinat.pdf
# Tebeau - 2010 - Sculpted Landscapes Art & Place in Cleveland's Cu.pdf
# Collins - 1979 - Sur l'histoire fiscale du XVIIe siècle les impôts.pdf
# Hamilton - 2017 - Pierre de L'Estoile and his World in the Wars of R.pdf
# Ladurie - 1974 - L'histoire immobile.pdf
# L''Histoire universelle du sieur d''Aubigné....pdf
# Tinguely_2000_L'écriture du Levant à la Renaissance.pdf
# Smither - 1991 - The St. Bartholomew's Day Massacre and Images of K.pdf
# Watt - 2020 - The Consistory and Social Discipline in Calvin's Geneva.pdf
# Bremond d'Ars - 1884 - Le père de Madame de Rambouillet. Jean de Vivonne,.pdf
# Lesure_1986_Les Relations Franco-Ottomanes a L'Épreuve des Guerres de Religion (1560-1594).pdf
# Isom-Verhaaren - 2006 - Royal French Women in the Ottoman Sultans' Harem .pdf
# Garnier - 2008 - L'Alliance impie François Ier et Soliman le Magni.pdf
# Auchterlonie - 2000 - A Turk of the West Sir Edgar Vincent's Career in .pdf
# Robert - 2013 - Constructions of Home, Front, and Women's Military Employment in First-World-War Britain A Spat.pdf
# Tyerman - 2007 - God's war a new history of the crusades.pdf
# L'histoire de France enrichie des plus notables occurrances survenues provinces de l'Europe et pays voisins.pdf
# Buchanan - 2011 - Why Gandhi Doesn't Belong at Wellington Railway St.pdf
# Dew - 2009 - Orientalism in Louis XIV's France.pdf
# O'Brien - 2010 - The Return of the Enlightenment.pdf
# Bourrilly - 1900 - La première ambassade d'Antonio Rincon en Orient (.pdf
# Wrynn - 2014 - Active Bodies A History of Women's Physical Educa.pdf
# Ribier - 1666 - Lettres Et Memoires D'Estat Des Roys, Princes, Amb.pdf
# Beer and Thompson - 2017 - Undergraduate and Graduate Research and Creative Activities  Faculty's evaluation, time commitment.pdf
# Isom-Verhaaren - The Sultan's Fleet.pdf
# Riess - 2015 - The Farmers'Game Baseball in Rural America by Dav.pdf
# Jouanna - 1968 - Recherches sur la notion d'honneur au XVIème siècl.pdf
# Serres-Histoire des choses memorable avenues en France, depuis l'an 1547.pdf
# Chesneau_Schefer_1887_Le voyage de Monsieur d'Aramon, ambassadeur pour le Roy en Levant.pdf
# 1601_« Negotiation de Mre François DE NOAILLES, evesque d'Ars, ambassadeur pour le.pdf
# Benedict_1978_The Saint Bartholomew's Massacres in the Provinces.pdf
# Kayili_Ari_2011_Examination of the Effects of the Montessori Method on Preschool Children's.pdf
# Pierre de L'Estoile_1875_Mémoires-journaux de Pierre de L'Estoile.pdf
# Parrott_2001_Richelieu's Army.pdf
# Kitab Nasir al-Din ala 'l-qawm - Qasim al-Hajari, Ahmad Ibn.pdf
# Çirakman - 2001 - From Tyranny to Despotism The Enlightenment's Une.pdf
# MUHANNA - 2010 - THE SULTAN'S NEW CLOTHES OTTOMAN—MAMLUK GIFT EXCH.pdf
# Preston - 2022 - A chronicle of Kappan's coverage of the reading wa.pdf
# Sharpe - 2015 - Liberty's Dawn A People's History of the Industri.pdf
# Watenpaugh - 2010 - The League of Nations' Rescue of Armenian Genocide.pdf
# Taşkesenli̇Oğlu - 74 NUMARALI MÜHİMME DEFTERİ' NİN TRANSKRİPSİYONU V.pdf
# Dodman - 2016 - Learning How to Feel Children's Literature and Em.pdf
# Rogers - 1993 - The Military Revolutions of the Hundred Years' War.pdf
# Finkel_2007_Osman's Dream.pdf
# D'Alexandrie a Istanbul - Bernard Yvelise.pdf
# ÖZBARAN - 2001 - Ottomans as 'Rumes' in Portuguese Sources in the S.pdf
# McCluskey - 2015 - 'Les ennemis du nom Chrestien' echoes of the crus.pdf
# Justifier l'Injustifiable.pdf
# Caron - 2010 - 'Killed by its Mother' Infanticide in Providence .pdf
# ORBANDALE et al_1662_L'Illustre Orbandale, ou l'histoire ancienne et moderne de la ville et cité de.pdf
# BRUMMETT - 2001 - THE OTTOMANS AS A WORLD POWER WHAT WE DON'T KNOW .pdf
# Sypher - 1980 - Faisant ce qu'il leur vient a plaisir The Image.pdf
# Cohen - 2015 - Paolina's Innocence Child Abuse in Casanova's Ven.pdf
# Cresti_2005_La population d'Alger et son évolution durant l'époque ottomane.pdf
# Kafadar. A Rome of One's Own.pdf
# O'Brien - 2010 - The Return of the Enlightenment.pdf
# Foley - 2006 - What's in a Name The Development of Strategies of Attrition on the Western Front, 19141918.pdf
# Korsch et al_2007_Diplomatic Gifts on Henri III's Visit to Venice in 1574.pdf
# Rady - 2023 - Violence, the City, and 'The Blue Angel'.pdf
# Bacqué-Grammont - 1970 - Une liste ottomane de princes et d'apanages abu'l-.pdf
# Bourrilly - 1901 - L'AMBASSADE DE LA FOREST ET DE MARILLAC A CONSTANT.pdf
# Beer and Thompson - 2017 - Undergraduate and Graduate Research and Creative Activities  Faculty's evaluation, time commitment.pdf
# O'Brien_2010_The Return of the Enlightenment.pdf
# Graf_2017_The Sultan's renegades.pdf
# Parrott - 2001 - Richelieu's Army War, Government, and Society in .pdf
# O'Brien_2010_The Return of the Enlightenment.pdf
# Blair - 1990 - Tycho Brahe's Critique of Copernicus and the Coper.pdf
# Feridun et al. - 2012 - Nüzhet-i esrârü'l-ahyâr der-ahbâr-ı sefer-i Sigetv.pdf
# Bourrilly - 1901 - L'AMBASSADE DE LA FOREST ET DE MARILLAC A CONSTANT.pdf
# Skilliter - 1976 - THE SULTAN'S MESSENGER, GABRIEL DEFRENS; AN OTTOMA.pdf
# Boucai - 2014 - Queer America A People's GLBT History of the Unit.pdf
# Skilliter - 1976 - THE SULTAN'S MESSENGER, GABRIEL DEFRENS; AN OTTOMA.pdf
# Ross_1896_The Early Years of Shāh Isma'īl, Founder of the Ṣafavī Dynasty.pdf
# Ribier_1666_Lettres et memoires d'estat, des roys, princes, ambassadeurs, et autres.pdf
# Haran - 1998 - Les droits de la couronne de France sur l'Empire a.pdf
# Robert - 2013 - Constructions of Home, Front, and Women's Military Employment in First-World-War Britain A Spat.pdf
# Dursteler-Education and Identity in Constantinople's Latin Rite Community, c. 1600.pdf
# Çirakman - 2001 - From Tyranny to Despotism The Enlightenment's Une.pdf
# Keller - 1952 - MICHEL DE L'HOSPITAL AND THE EDICT OF TOLERATION O.pdf
# Adi - 113 NUMARALI MUHiMME DEFTERi'NiN (H. 1112-11151M.1.pdf
# Saint-Priest_1877_Mémoires sur l'Ambassade de France en Turquie et sur le commerce des Français.pdf
# Lafaist_1836_Archives curieuses de l'histoire de France.pdf
# Vatin - 2006 - Ces Messieurs de Galata. Note sur Deux Rapports d'.pdf
# Ritchie - 1939 - Léonard Limosin's Triumph of the Faith, with Portr.pdf
# Thou et al_1734_Histoire universelle de Jacque-Auguste de Thou depuis 1543 jusqu'en 1607.pdf
# Bull - 2015 - The Pleasure's All Mine A History of Perverse Sex.pdf
# Graf_2017_The Sultan's renegades.pdf
# Vatin - 1992 - Note sur l'attitude des sultans ottomans et de leu.pdf
# Bennigsen and Lemercier-Quelquejay - 1973 - La Moscovie, l'Empire ottoman et la crise successo.pdf
# Pasierowska - 2017 - Screech Owls Allus Holler 'round the House before.pdf
# Ferguson - 1978 - The Exile's Defense DuBellay's La Deffence et ill.pdf
# Kosior - 2021 - HENRY VALOIS'S COURT AND ELECTIVE KINGSHIP IN THE .pdf
# Goldhagen and Wohlgelernter - 1997 - Hitler's Willing Executioners.pdf
# Kohler-Hausmann - 2010 - The Attila the Hun Law New York's Rockefeller D.pdf
# Ekirch - 2014 - Evening's Empire A History of the Night in Early .pdf
# Davis_1976_Women's History in Transition.pdf
# Davis_1988_History's Two Bodies.pdf
# Tallon - 2004 - Le clergé de France et l'obéissance due au roi trè.pdf
# d'Arbaleste - 2009 - Escape from the Massacre, 1572.pdf
# Pipkin - 2015 - Sex and Drugs before Rock 'n' Roll Youth Culture .pdf
# Kley - 1971 - Europe's Discovery of China and the Writing of W.pdf
# Citlak_Aysegul_Osmanli-Fransa iliskileri_Muteferrika Suleyman Aga'nin Fransa Elciligi_1669-1670_MA.pdf
# Crouzet_1983_La représentation du temps à l'époque de la Ligue.pdf
# Wilkin - 2003 - Figuring the Dead Descartes Claude Clerselier's H.pdf
# 1905_Les sources inédites de l'histoire du Maroc.pdf
# Foley - 2006 - What's in a Name The Development of Strategies of Attrition on the Western Front, 19141918.pdf
# Villeroy_Du Mesnil_1622_Memoires d'estat.pdf
# 108
